# %% [markdown]
# # Entrenando un Modelo Markoviano Latente (HMM)

# %% [markdown]
# ## Corpus de español:
#
# * AnCora | Github: https://github.com/UniversalDependencies/UD_Spanish-AnCora
#
# * usamos el conllu parser para leer el corpus: https://pypi.org/project/conllu/
#
# * Etiquetas Universal POS (Documentación): https://universaldependencies.org/u/pos/

# %%
#@title dependencias previas
# !pip install conllu
# !git clone https://github.com/UniversalDependencies/UD_Spanish-AnCora.git
# Out:
# Collecting conllu
#   Downloading conllu-5.0.1-py3-none-any.whl (16 kB)
# Installing collected packages: conllu
# Successfully installed conllu-5.0.1
# Cloning into 'UD_Spanish-AnCora'...
# remote: Enumerating objects: 1371, done.
# remote: Counting objects: 100% (387/387), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 1371 (delta 301), reused 381 (delta 295), pack-reused 984
# Receiving objects: 100% (1371/1371), 434.03 MiB | 24.13 MiB/s, done.
# Resolving deltas: 100% (994/994), done.

# %%
#@title leyendo el corpus AnCora
from conllu import parse_incr #Lectura dek archivo
wordList = [] #Crear una lista vacia
data_file = open("UD_Spanish-AnCora/es_ancora-ud-dev.conllu", "r", encoding="utf-8") #Selecciona el archivo en el datafile
for tokenlist in parse_incr(data_file): #Por cada lista de tokens el resultado. Parse para generar lista de tokens del resultado del datafile
    print(tokenlist.serialize()) #imprime la lista de tokens serializada (de manera estetica)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# 36	vez	vez	NOUN	ncfs000	Gender=Fem|Number=Sing	33	obl	33:obl	SpaceAfter=No|ArgTem=argM:adv
# 37	,	,	PUNCT	fc	PunctType=Comm	36	punct	36:punct	_
# 38	17	17	NUM	_	NumForm=Digit|NumType=Card	40	nummod	40:nummod	Entity=(CESSCASTP20011002160c16--3-gstype:gen
# 39	nuevos	nuevo	ADJ	aq0mp0	Gender=Masc|Number=Plur	40	amod	40:amod	_
# 40	fichajes	fichaje	NOUN	ncmp000	Gender=Masc|Number=Plur	33	obj	33:obj	SpaceAfter=No|ArgTem=arg1:pat
# 41	,	,	PUNCT	fc	PunctType=Comm	45	punct	45:punct	_
# 42	entre	entre	ADP	sps00	_	43	case	43:case	_
# 43	ellos	él	PRON	pp3mp000	Case=Acc,Nom|Gender=Masc|Number=Plur|Person=3|PronType=Prs	45	nmod	45:nmod	Entity=(CESSCASTP20011002160c16--1-CorefType:ident,gstype:gen)
# 44	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	45	det	45:det	Entity=(NOCOREF:Spec.person-person-2-gstype:spec
# 45	portugués	portugués	NOUN	ncms000	Gender=Masc|Number=Sing	40	appos	40:appos	_
# 46	Conceiçao	Conceiçao	PROPN	np00000	_	45	appos	45:appos	Entity=(NOCOREF:Spec.person-person-1-gstype:spec)NOCOREF:Spec.person)
# 47	(	(	PUNCT	fpa	PunctSide=Ini|PunctType=Brck	48	punct	48:punct	SpaceAfter=No|Entity=(NOCOREF:Spec.organization-organization-2-gstype:spec
# 48	Parma	Parma	PROPN	np00000	_	45	appos	45:appos	SpaceAfter=No
# 49	)	)	PUNCT	fpt	PunctSide=Fin|PunctType=Brck	48	punct	48:punct	SpaceAfter=No|Entity=NOCOREF:Spec.organization)
# 50	,	,	PUNCT	fc	PunctType=Comm	52	punct	52:punct	_
# 51	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	52	det	52:det	Entity=(NOCOREF:Spec-other-2-gstype:spec,HomoDD
# 52	argentinos	argentino	NOUN	ncmp000	Gender=Masc|Number=Plur	45	appos	45:appos	_
# 53	Guglielminpietro	Guglielminpietro	PROPN	np00000	_	52	appos	52:appos	_
# 54	(	(	PUNCT	fpa	PunctSide=Ini|PunctType=Brck	55	punct	55:punct	SpaceAfter=No|Entity=(NOCOREF:Spec.organization-organization-2-gstype:spec
# 55	Milan	Milan	PROPN	np00000	_	53	flat	53:flat	SpaceAfter=No
# 56	)	)	PUNCT	fpt	PunctSide=Fin|PunctType=Brck	55	punct	55:punct	Entity=NOCOREF:Spec.organization)
# 57	y	y	CCONJ	cc	_	58	cc	58:cc	_
# 58	Vivas	Vivas	PROPN	np00000	_	53	conj	53:conj	_
# 59	(	(	PUNCT	fpa	PunctSide=Ini|PunctType=Brck	60	punct	60:punct	SpaceAfter=No|Entity=(NOCOREF:Spec.organization-organization-2-gstype:spec
# 60	Arsenal	Arsenal	PROPN	np00000	_	58	flat	58:flat	SpaceAfter=No
# 61	)	)	PUNCT	fpt	PunctSide=Fin|PunctType=Brck	60	punct	60:punct	SpaceAfter=No|Entity=NOCOREF:Spec.organization)NOCOREF:Spec)
# 62	,	,	PUNCT	fc	PunctType=Comm	65	punct	65:punct	_
# 63	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	65	det	65:det	Entity=(NOCOREF:Spec-other-3-gstype:spec,HomoDD
# 64	turcos	turco	NOUN	ncmp000	Gender=Masc|Number=Plur	65	nmod	65:nmod	_
# 65	Emre	Emre	PROPN	np00000	_	45	appos	45:appos	_
# 66	y	y	CCONJ	cc	_	67	cc	67:cc	_
# 67	Okan	Okan	PROPN	np00000	_	65	conj	65:conj	_
# 68	(	(	PUNCT	fpa	PunctSide=Ini|PunctType=Brck	69	punct	69:punct	SpaceAfter=No|Entity=(NOCOREF:Spec.organization-organization-2-gstype:spec
# 69	Galatasaray	Galatasaray	PROPN	np00000	_	65	appos	65:appos	SpaceAfter=No
# 70	)	)	PUNCT	fpt	PunctSide=Fin|PunctType=Brck	69	punct	69:punct	SpaceAfter=No|Entity=NOCOREF:Spec.organization)NOCOREF:Spec)
# 71	,	,	PUNCT	fc	PunctType=Comm	73	punct	73:punct	_
# 72	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	73	det	73:det	Entity=(NOCOREF:Spec-other-2-gstype:spec,HomoDD
# 73	italianos	italiano	NOUN	ncmp000	Gender=Masc|Number=Plur	45	appos	45:appos	_
# 74	Toldo	Toldo	PROPN	np00000	_	73	appos	73:appos	_
# 75	(	(	PUNCT	fpa	PunctSide=Ini|PunctType=Brck	76	punct	76:punct	SpaceAfter=No|Entity=(NOCOREF:Spec.organization-organization-2-gstype:spec
# 76	Fiorentina	Fiorentina	PROPN	np00000	_	74	flat	74:flat	SpaceAfter=No
# 77	)	)	PUNCT	fpt	PunctSide=Fin|PunctType=Brck	76	punct	76:punct	Entity=NOCOREF:Spec.organization)
# 78	y	y	CCONJ	cc	_	79	cc	79:cc	_
# 79	Materazzi	Materazzi	PROPN	np00000	_	74	conj	74:conj	_
# 80	(	(	PUNCT	fpa	PunctSide=Ini|PunctType=Brck	81	punct	81:punct	SpaceAfter=No|Entity=(NOCOREF:Spec.organization-organization-2-gstype:spec
# 81	Perugia	Perugia	PROPN	np00000	_	79	flat	79:flat	SpaceAfter=No
# 82	)	)	PUNCT	fpt	PunctSide=Fin|PunctType=Brck	81	punct	81:punct	SpaceAfter=No|Entity=NOCOREF:Spec.organization)NOCOREF:Spec)
# 83	,	,	PUNCT	fc	PunctType=Comm	85	punct	85:punct	_
# 84	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	85	det	85:det	Entity=(NOCOREF:Spec.person-person-2-gstype:spec
# 85	brasileño	brasileño	NOUN	ncms000	Gender=Masc|Number=Sing	45	appos	45:appos	_
# 86	Adriano	Adriano	PROPN	np00000	_	85	appos	85:appos	Entity=(NOCOREF:Spec.person-person-1-gstype:spec(NOCOREF:Spec.person-person-1-gstype:spec)
# 87	(	(	PUNCT	fpa	PunctSide=Ini|PunctType=Brck	88	punct	88:punct	SpaceAfter=No|Entity=(NOCOREF:Spec.organization-organization-2-gstype:spec
# 88	Flamengo	Flamengo	PROPN	np00000	_	86	flat	86:flat	SpaceAfter=No
# 89	)	)	PUNCT	fpt	PunctSide=Fin|PunctType=Brck	88	punct	88:punct	Entity=NOCOREF:Spec.organization)NOCOREF:Spec.person)NOCOREF:Spec.person)
# 90	o	o	CCONJ	cc	_	93	cc	93:cc	_
# 91	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	93	det	93:det	Entity=(NOCOREF:Spec.person-person-3-gstype:spec(CESSCASTP20011002160c14--3-CorefType:ident
# 92	propio	propio	ADJ	aq0ms0	Gender=Masc|Number=Sing	93	amod	93:amod	_
# 93	Kallon	Kallon	PROPN	np00000	_	45	conj	45:conj	Entity=CESSCASTP20011002160c14)
# 94	(	(	PUNCT	fpa	PunctSide=Ini|PunctType=Brck	95	punct	95:punct	SpaceAfter=No|Entity=(NOCOREF:Spec.organization-organization-2-gstype:spec
# 95	Vicenza	Vicenza	PROPN	np00000	_	93	flat	93:flat	SpaceAfter=No
# 96	)	)	PUNCT	fpt	PunctSide=Fin|PunctType=Brck	95	punct	95:punct	SpaceAfter=No|Entity=NOCOREF:Spec.organization)NOCOREF:Spec.person)CESSCASTP20011002160c16)CESSCASTP20011002160c2)CESSCASTP20011002160c15)CESSCASTP20011002160c14)
# 97	.	.	PUNCT	fp	PunctType=Peri	16	punct	16:punct	_
#
#
# # sent_id = CESS-CAST-P-20011002-160-s14
# # text = Después de los fracasos con Lippi y Tardelli, la sensatez que ha traído Cúper supone ahora la gran esperanza para un club que no gana el scudetto desde 1989.
# 1	Después	después	ADV	rg	_	16	advmod	16:advmod	ArgTem=argM:tmp
# 2	de	de	ADP	sps00	_	4	case	4:case	_
# 3	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	4	det	4:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 4	fracasos	fracaso	NOUN	ncmp000	Gender=Masc|Number=Plur	1	obl	1:obl	_
# 5	con	con	ADP	sps00	_	6	case	6:case	_
# 6	Lippi	Lippi	PROPN	np00000	_	4	nmod	4:nmod	ArgTem=argM:adv
# 7	y	y	CCONJ	cc	_	8	cc	8:cc	_
# 8	Tardelli	Tardelli	PROPN	np00000	_	6	conj	6:conj	SpaceAfter=No|Entity=NOCOREF:Gen)
# 9	,	,	PUNCT	fc	PunctType=Comm	1	punct	1:punct	_
# 10	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	11	det	11:det	Entity=(CESSCASTP20011002160c17--2-gstype:gen,HomoDD
# 11	sensatez	sensatez	NOUN	ncfs000	Gender=Fem|Number=Sing	16	nsubj	16:nsubj	ArgTem=arg1:tem
# 12	que	que	PRON	pr0cn000	PronType=Rel	14	obj	14:obj	ArgTem=arg1:pat|Entity=(CESSCASTP20011002160c17--1-CorefType:ident,gstype:gen)
# 13	ha	haber	AUX	vaip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	14	aux	14:aux	_
# 14	traído	traer	VERB	vmp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	11	acl	11:acl	_
# 15	Cúper	Cúper	PROPN	np00000	_	14	nsubj	14:nsubj	ArgTem=arg0:agt|Entity=(CESSCASTP20011002160c5-person-1-CorefType:ident,gstype:spec)CESSCASTP20011002160c17)
# 16	supone	suponer	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	0:root	_
# 17	ahora	ahora	ADV	rg	_	16	advmod	16:advmod	ArgTem=argM:tmp
# 18	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	20	det	20:det	Entity=(NOCOREF:Gen--3-gstype:gen,HomoDD
# 19	gran	gran	ADJ	aq0cs0	Number=Sing	20	amod	20:amod	_
# 20	esperanza	esperanza	NOUN	ncfs000	Gender=Fem|Number=Sing	16	obj	16:obj	ArgTem=arg2:atr
# 21	para	para	ADP	sps00	_	23	case	23:case	_
# 22	un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	23	det	23:det	Entity=(CESSCASTP20011002160c2-organization-2-CorefType:ident,gstype:spec
# 23	club	club	NOUN	ncms000	Gender=Masc|Number=Sing	20	nmod	20:nmod	ArgTem=arg0:agt
# 24	que	que	PRON	pr0cn000	PronType=Rel	26	nsubj	26:nsubj	ArgTem=arg0:agt|Entity=(CESSCASTP20011002160c2-organization-1-CorefType:ident,gstype:spec)
# 25	no	no	ADV	rn	Polarity=Neg	26	advmod	26:advmod	_
# 26	gana	ganar	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	23	acl	23:acl	_
# 27	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	28	det	28:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 28	scudetto	scudetto	NOUN	nc00000	_	26	obj	26:obj	ArgTem=arg1:pat|Entity=NOCOREF:Gen)
# 29	desde	desde	ADP	sps00	_	30	case	30:case	_
# 30	1989	1989	NOUN	_	AdvType=Tim	26	obl	26:obl	SpaceAfter=No|ArgTem=argM:tmp|Entity=(NOCOREF:Spec.date-time-1-gstype:spec)CESSCASTP20011002160c2)NOCOREF:Gen)
# 31	.	.	PUNCT	fp	PunctType=Peri	16	punct	16:punct	_
#
#
# # global.Entity = eid-etype-head-other
# # newdoc id = CESS-CAST-P-20011002-168
# # sent_id = CESS-CAST-P-20011002-168-s1
# # text = El cine argentino se asocia a una cierta locuacidad verbal o, en algunos casos, como el de Eliseo Subiela, a una forma muy personal de tratar los elementos propios del fantástico.
# 1	El	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	2	det	2:det	Entity=(CESSCASTP20011002168c2--2-gstype:gen,HomoDD
# 2	cine	cine	NOUN	ncms000	Gender=Masc|Number=Sing	5	nsubj	5:nsubj	ArgTem=arg1:tem
# 3	argentino	argentino	ADJ	aq0ms0	Gender=Masc|Number=Sing	2	amod	2:amod	Entity=CESSCASTP20011002168c2)
# 4	se	él	PRON	p0000000	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	5	obj	5:obj	_
# 5	asocia	asociar	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	0:root	_
# 6	a	a	ADP	sps00	_	9	case	9:case	_
# 7	una	uno	DET	di0fs0	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	9	det	9:det	Entity=(NOCOREF:Gen--3-gstype:gen
# 8	cierta	cierto	DET	di0fs0	Gender=Fem|Number=Sing|PronType=Ind	7	det	7:det	_
# 9	locuacidad	locuacidad	NOUN	ncfs000	Gender=Fem|Number=Sing	5	obl:arg	5:obl:arg	ArgTem=arg2:cot
# 10	verbal	verbal	ADJ	aq0cs0	Number=Sing	9	amod	9:amod	Entity=NOCOREF:Gen)
# 11	o	o	CCONJ	cc	_	15	cc	15:cc	SpaceAfter=No
# 12	,	,	PUNCT	fc	PunctType=Comm	15	punct	15:punct	_
# 13	en	en	ADP	sps00	_	15	case	15:case	_
# 14	algunos	alguno	DET	di0mp0	Gender=Masc|Number=Plur|PronType=Ind	15	det	15:det	Entity=(NOCOREF:Gen--2-gstype:gen
# 15	casos	caso	NOUN	ncmp000	Gender=Masc|Number=Plur	9	conj	9:conj	SpaceAfter=No
# 16	,	,	PUNCT	fc	PunctType=Comm	18	punct	18:punct	_
# 17	como	como	SCONJ	cs	_	18	mark	18:mark	_
# 18	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	15	det	15:det	Entity=(NOCOREF:Gen--1-gstype:gen
# 19	de	de	ADP	sps00	_	18	case	18:case	_
# 20	Eliseo	Eliseo	PROPN	np00000	_	18	nmod	18:nmod	Entity=(NOCOREF:Spec.person-person-1-gstype:spec|MWE=Eliseo_Subiela|MWEPOS=PROPN
# 21	Subiela	Subiela	PROPN	_	_	20	flat	20:flat	SpaceAfter=No|Entity=NOCOREF:Spec.person)NOCOREF:Gen)NOCOREF:Gen)
# 22	,	,	PUNCT	fc	PunctType=Comm	15	punct	15:punct	_
# 23	a	a	ADP	sps00	_	15	case	15:case	_
# 24	una	uno	DET	di0fs0	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	25	det	25:det	Entity=(NOCOREF:Gen--2-gstype:gen
# 25	forma	forma	NOUN	ncfs000	Gender=Fem|Number=Sing	15	nmod	15:nmod	_
# 26	muy	mucho	ADV	rg	_	27	advmod	27:advmod	_
# 27	personal	personal	ADJ	aq0cs0	Number=Sing	25	amod	25:amod	_
# 28	de	de	ADP	sps00	_	29	mark	29:mark	_
# 29	tratar	tratar	VERB	vmn0000	VerbForm=Inf	25	acl	25:acl	_
# 30	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	31	det	31:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 31	elementos	elemento	NOUN	ncmp000	Gender=Masc|Number=Plur	29	obj	29:obj	ArgTem=arg1:pat
# 32	propios	propio	ADJ	aq0mp0	Gender=Masc|Number=Plur	31	amod	31:amod	_
# 33-34	del	_	_	_	_	_	_	_	_
# 33	de	de	ADP	spcms	_	35	case	35:case	_
# 34	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	35	det	35:det	_
# 35	fantástico	fantástico	ADJ	aq0ms0	Gender=Masc|Number=Sing	31	amod	31:amod	SpaceAfter=No|Entity=(NOCOREF:Gen--1-gstype:gen,HomoDD)NOCOREF:Gen)NOCOREF:Gen)
# 36	.	.	PUNCT	fp	PunctType=Peri	5	punct	5:punct	_
#
#
# # sent_id = CESS-CAST-P-20011002-168-s2
# # text = Con La ciénaga, primer filme de la realizadora Lucrecia Martel, el cine argentino deja a un lado la palabra, aunque en la mayoría de sus secuencias se hable bastante, para crear a través del sonido, el decorado y el gesto del actor una atmósfera auténticamente inquietante y malsana.
# 1	Con	con	ADP	sps00	_	3	case	3:case	_
# 2	La	el	DET	np00000	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	3	det	3:det	MWE=La_ciénaga|MWEPOS=PROPN|ArgTem=argM:adv|Entity=(CESSCASTP20011002168c1-other-2-gstype:spec
# 3	ciénaga	ciénaga	PROPN	_	_	16	obl	16:obl	SpaceAfter=No
# 4	,	,	PUNCT	fc	PunctType=Comm	6	punct	6:punct	Entity=(CESSCASTP20011002168c1-other-3-CorefType:pred.definit,gstype:spec
# 5	primer	primero	ADJ	ao0ms0	Gender=Masc|Number=Sing|NumType=Ord	6	amod	6:amod	_
# 6	filme	filme	NOUN	ncms000	Gender=Masc|Number=Sing	2	appos	2:appos	_
# 7	de	de	ADP	sps00	_	9	case	9:case	_
# 8	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	9	det	9:det	Entity=(CESSCASTP20011002168c15-person-2-gstype:spec
# 9	realizadora	realizadora	NOUN	ncfs000	Gender=Fem|Number=Sing	6	nmod	6:nmod	_
# 10	Lucrecia	Lucrecia	PROPN	np00000	_	9	appos	9:appos	MWE=Lucrecia_Martel|MWEPOS=PROPN|Entity=(NOCOREF:Spec.person-person-1-gstype:spec
# 11	Martel	Martel	PROPN	_	_	10	flat	10:flat	SpaceAfter=No|Entity=NOCOREF:Spec.person)CESSCASTP20011002168c15)CESSCASTP20011002168c1)CESSCASTP20011002168c1)
# 12	,	,	PUNCT	fc	PunctType=Comm	3	punct	3:punct	_
# 13	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	14	det	14:det	Entity=(CESSCASTP20011002168c2--2-CorefType:ident,gstype:gen,HomoDD
# 14	cine	cine	NOUN	ncms000	Gender=Masc|Number=Sing	16	nsubj	16:nsubj	ArgTem=arg0:agt
# 15	argentino	argentino	ADJ	aq0ms0	Gender=Masc|Number=Sing	14	amod	14:amod	Entity=CESSCASTP20011002168c2)
# 16	deja	dejar	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	0:root	_
# 17	a	a	ADP	sps00	_	19	case	19:case	_
# 18	un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	19	det	19:det	_
# 19	lado	lado	NOUN	ncms000	Gender=Masc|Number=Sing	16	obl	16:obl	ArgTem=argL:
# 20	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	21	det	21:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 21	palabra	palabra	NOUN	ncfs000	Gender=Fem|Number=Sing	16	obj	16:obj	SpaceAfter=No|ArgTem=arg1:pat|Entity=NOCOREF:Gen)
# 22	,	,	PUNCT	fc	PunctType=Comm	31	punct	31:punct	_
# 23	aunque	aunque	SCONJ	cs	_	31	mark	31:mark	_
# 24	en	en	ADP	sps00	_	29	case	29:case	_
# 25	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	26	det	26:det	Entity=(NOCOREF:Gen--5-gstype:gen,HomoDD
# 26	mayoría	mayoría	NOUN	ncfs000	Gender=Fem|Number=Sing	29	nmod	29:nmod	_
# 27	de	de	ADP	sps00	_	26	case	26:case	_
# 28	sus	su	DET	dp3cp0	Number=Plur|Person=3|Poss=Yes|PronType=Prs	26	det	26:det	Entity=(CESSCASTP20011002168c1-other-1-CorefType:ident,gstype:spec)
# 29	secuencias	secuencia	NOUN	ncfp000	Gender=Fem|Number=Plur	31	obl	31:obl	ArgTem=argM:loc|Entity=NOCOREF:Gen)
# 30	se	él	PRON	p0000000	Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	31	expl:impers	31:expl:impers	_
# 31	hable	hablar	VERB	vmsp3s0	Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	16	advcl	16:advcl	_
# 32	bastante	bastante	ADV	rg	_	31	advmod	31:advmod	SpaceAfter=No|ArgTem=argM:adv
# 33	,	,	PUNCT	fc	PunctType=Comm	31	punct	31:punct	_
# 34	para	para	ADP	sps00	_	35	mark	35:mark	_
# 35	crear	crear	VERB	vmn0000	VerbForm=Inf	16	advcl	16:advcl	ArgTem=argM:fin
# 36	a	a	ADP	spcms	_	40	case	40:case	MWE=a_través_del|MWEPOS=ADP
# 37	través	través	NOUN	_	_	36	fixed	36:fixed	_
# 38-39	del	_	_	_	_	_	_	_	_
# 38	de	de	ADP	_	_	36	fixed	36:fixed	_
# 39	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	40	det	40:det	_
# 40	sonido	sonido	NOUN	ncms000	Gender=Masc|Number=Sing	35	obl	35:obl	SpaceAfter=No|ArgTem=argM:adv|Entity=(NOCOREF:Gen--1-gstype:gen,HomoDD)
# 41	,	,	PUNCT	fc	PunctType=Comm	43	punct	43:punct	_
# 42	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	43	det	43:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 43	decorado	decorado	NOUN	ncms000	Gender=Masc|Number=Sing	40	appos	40:appos	Entity=NOCOREF:Gen)
# 44	y	y	CCONJ	cc	_	46	cc	46:cc	_
# 45	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	46	det	46:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 46	gesto	gesto	NOUN	ncms000	Gender=Masc|Number=Sing	40	conj	40:conj	_
# 47-48	del	_	_	_	_	_	_	_	_
# 47	de	de	ADP	spcms	_	49	case	49:case	_
# 48	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	49	det	49:det	_
# 49	actor	actor	NOUN	ncms000	Gender=Masc|Number=Sing	46	nmod	46:nmod	Entity=(NOCOREF:Gen--1-gstype:gen,HomoDD)NOCOREF:Gen)
# 50	una	uno	DET	di0fs0	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	51	det	51:det	Entity=(NOCOREF:Gen--2-gstype:gen
# 51	atmósfera	atmósfera	NOUN	ncfs000	Gender=Fem|Number=Sing	35	obj	35:obj	ArgTem=arg1:pat
# 52	auténticamente	auténticamente	ADV	rg	_	53	advmod	53:advmod	_
# 53	inquietante	inquietante	ADJ	aq0cs0	Number=Sing	51	amod	51:amod	_
# 54	y	y	CCONJ	cc	_	55	cc	55:cc	_
# 55	malsana	malsano	ADJ	aq0fs0	Gender=Fem|Number=Sing	53	conj	53:conj	SpaceAfter=No|Entity=NOCOREF:Gen)
# 56	.	.	PUNCT	fp	PunctType=Peri	16	punct	16:punct	_
#
#
# # sent_id = CESS-CAST-P-20011002-168-s3
# # text = La primera secuencia del filme parece situarnos en otro mundo, decrépito y decadente, fantasmal y esperpéntico.
# 1	La	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	3	det	3:det	Entity=(CESSCASTP20011002168c12--3-gstype:gen,HomoDD
# 2	primera	primero	ADJ	ao0fs0	Gender=Fem|Number=Sing|NumType=Ord	3	amod	3:amod	_
# 3	secuencia	secuencia	NOUN	ncfs000	Gender=Fem|Number=Sing	7	nsubj	7:nsubj	ArgTem=arg1:tem
# 4-5	del	_	_	_	_	_	_	_	_
# 4	de	de	ADP	spcms	_	6	case	6:case	_
# 5	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	6	det	6:det	_
# 6	filme	filme	NOUN	ncms000	Gender=Masc|Number=Sing	3	nmod	3:nmod	Entity=(CESSCASTP20011002168c1-other-1-CorefType:ident,gstype:spec)CESSCASTP20011002168c12)
# 7	parece	parecer	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	0:root	_
# 8-9	situarnos	_	_	_	_	_	_	_	_
# 8	situar	situar	VERB	vmn0000	VerbForm=Inf	7	ccomp	7:ccomp	ArgTem=arg2:atr|Entity=(CESSCASTP20011002168c14--1
# 9	nos	yo	PRON	_	Case=Acc|Number=Plur|Person=1|PrepCase=Npr|PronType=Prs	8	obj	8:obj	Entity=CESSCASTP20011002168c14)
# 10	en	en	ADP	sps00	_	12	case	12:case	_
# 11	otro	otro	DET	di0ms0	Gender=Masc|Number=Sing|PronType=Ind	12	det	12:det	Entity=(NOCOREF:Gen--2-gstype:gen
# 12	mundo	mundo	NOUN	ncms000	Gender=Masc|Number=Sing	8	obl	8:obl	SpaceAfter=No|ArgTem=arg2:loc
# 13	,	,	PUNCT	fc	PunctType=Comm	14	punct	14:punct	_
# 14	decrépito	decrépito	ADJ	aq0ms0	Gender=Masc|Number=Sing	12	amod	12:amod	_
# 15	y	y	CCONJ	cc	_	16	cc	16:cc	_
# 16	decadente	decadente	ADJ	aq0cs0	Number=Sing	14	conj	14:conj	SpaceAfter=No
# 17	,	,	PUNCT	fc	PunctType=Comm	18	punct	18:punct	_
# 18	fantasmal	fantasmal	ADJ	aq0cs0	Number=Sing	14	conj	14:conj	_
# 19	y	y	CCONJ	cc	_	20	cc	20:cc	_
# 20	esperpéntico	esperpéntico	ADJ	aq0ms0	Gender=Masc|Number=Sing	18	conj	18:conj	SpaceAfter=No|Entity=NOCOREF:Gen)
# 21	.	.	PUNCT	fp	PunctType=Peri	7	punct	7:punct	_
#
#
# # sent_id = CESS-CAST-P-20011002-168-s4
# # text = Una serie de hombres y mujeres de apariencia burguesa, demacrados y parapetados tras sus gafas de sol, consumen las últimas gotas de alcohol de una juerga nocturna junto a una especie de piscina cuyas aguas de color indeterminado invitan a cualquier cosa menos a un refrescante chapuzón.
# 1	Una	uno	DET	di0fs0	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	2	det	2:det	Entity=(CESSCASTP20011002168c5--2-gstype:gen
# 2	serie	serie	NOUN	ncfs000	Gender=Fem|Number=Sing	20	nsubj	20:nsubj	ArgTem=arg0:agt
# 3	de	de	ADP	sps00	_	4	case	4:case	_
# 4	hombres	hombre	NOUN	ncmp000	Gender=Masc|Number=Plur	2	nmod	2:nmod	_
# 5	y	y	CCONJ	cc	_	6	cc	6:cc	_
# 6	mujeres	mujer	NOUN	ncfp000	Gender=Fem|Number=Plur	4	conj	4:conj	Entity=(CESSCASTP20011002168c21--1-gstype:gen)
# 7	de	de	ADP	sps00	_	8	case	8:case	_
# 8	apariencia	apariencia	NOUN	ncfs000	Gender=Fem|Number=Sing	4	nmod	4:nmod	Entity=(NOCOREF:Gen--1-gstype:gen
# 9	burguesa	burgués	ADJ	aq0fs0	Gender=Fem|Number=Sing	8	amod	8:amod	SpaceAfter=No|ArgTem=arg2:atr|Entity=NOCOREF:Gen)
# 10	,	,	PUNCT	fc	PunctType=Comm	11	punct	11:punct	_
# 11	demacrados	demacrado	ADJ	aq0mpp	Gender=Masc|Number=Plur|VerbForm=Part	4	amod	4:amod	_
# 12	y	y	CCONJ	cc	_	13	cc	13:cc	_
# 13	parapetados	parapetado	ADJ	aq0mpp	Gender=Masc|Number=Plur|VerbForm=Part	11	conj	11:conj	_
# 14	tras	tras	ADP	sps00	_	16	case	16:case	_
# 15	sus	su	DET	dp3cp0	Number=Plur|Person=3|Poss=Yes|PronType=Prs	16	det	16:det	Entity=(NOCOREF:Gen--2-gstype:gen(CESSCASTP20011002168c5--1-CorefType:ident,gstype:gen)
# 16	gafas	gafas	NOUN	ncfp000	Gender=Fem|Number=Plur	13	obl	13:obl	ArgTem=argM:loc
# 17	de	de	ADP	sps00	_	18	case	18:case	_
# 18	sol	sol	NOUN	ncms000	Gender=Masc|Number=Sing	16	nmod	16:nmod	SpaceAfter=No|Entity=NOCOREF:Gen)
# 19	,	,	PUNCT	fc	PunctType=Comm	11	punct	11:punct	Entity=CESSCASTP20011002168c5)
# 20	consumen	consumir	VERB	vmip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	0	root	0:root	_
# 21	las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	23	det	23:det	Entity=(CESSCASTP20011002168c4--3-gstype:gen,HomoDD
# 22	últimas	último	ADJ	ao0fp0	Gender=Fem|Number=Plur|NumType=Ord	23	amod	23:amod	_
# 23	gotas	gota	NOUN	ncfp000	Gender=Fem|Number=Plur	20	obj	20:obj	ArgTem=arg1:pat
# 24	de	de	ADP	sps00	_	25	case	25:case	_
# 25	alcohol	alcohol	NOUN	ncms000	Gender=Masc|Number=Sing	23	nmod	23:nmod	_
# 26	de	de	ADP	sps00	_	28	case	28:case	_
# 27	una	uno	DET	di0fs0	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	28	det	28:det	Entity=(CESSCASTP20011002168c13--2-gstype:gen
# 28	juerga	juerga	NOUN	ncfs000	Gender=Fem|Number=Sing	23	nmod	23:nmod	_
# 29	nocturna	nocturno	ADJ	aq0fs0	Gender=Fem|Number=Sing	28	amod	28:amod	Entity=CESSCASTP20011002168c13)CESSCASTP20011002168c4)
# 30	junto	junto	ADJ	sps00	_	33	case	33:case	MWE=junto_a|MWEPOS=ADP
# 31	a	a	ADP	_	_	30	fixed	30:fixed	_
# 32	una	uno	DET	di0fs0	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	33	det	33:det	Entity=(CESSCASTP20011002168c22--2-gstype:gen
# 33	especie	especie	NOUN	ncfs000	Gender=Fem|Number=Sing	20	obl	20:obl	ArgTem=argM:loc
# 34	de	de	ADP	sps00	_	35	case	35:case	_
# 35	piscina	piscina	NOUN	ncfs000	Gender=Fem|Number=Sing	33	nmod	33:nmod	_
# 36	cuyas	cuyo	DET	pr0fp000	Gender=Fem|Number=Plur|Poss=Yes|PronType=Rel	37	nmod	37:nmod	Entity=(NOCOREF:Gen--2-gstype:gen(CESSCASTP20011002168c22--1-CorefType:ident,gstype:gen)
# 37	aguas	agua	NOUN	ncfp000	Gender=Fem|Number=Plur	41	nsubj	41:nsubj	ArgTem=arg0:agt
# 38	de	de	ADP	sps00	_	39	case	39:case	_
# 39	color	color	NOUN	ncms000	Gender=Masc|Number=Sing	37	nmod	37:nmod	Entity=(NOCOREF:Gen--1-gstype:gen
# 40	indeterminado	indeterminado	ADJ	aq0ms0	Gender=Masc|Number=Sing	39	amod	39:amod	Entity=NOCOREF:Gen)NOCOREF:Gen)
# 41	invitan	invitar	VERB	vmip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	35	acl	35:acl	_
# 42	a	a	ADP	sps00	_	44	case	44:case	_
# 43	cualquier	cualquiera	DET	di0cs0	Number=Sing|PronType=Ind	44	det	44:det	Entity=(NOCOREF:Gen--2-gstype:gen
# 44	cosa	cosa	NOUN	ncfs000	Gender=Fem|Number=Sing	41	obj	41:obj	ArgTem=arg2:tem
# 45	menos	menos	ADV	rg	Degree=Cmp	44	advmod	44:advmod	_
# 46	a	a	ADP	sps00	_	45	case	45:case	_
# 47	un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	49	det	49:det	Entity=(NOCOREF:Gen--3-gstype:gen
# 48	refrescante	refrescante	ADJ	aq0cs0	Number=Sing	49	amod	49:amod	_
# 49	chapuzón	chapuzón	NOUN	ncms000	Gender=Masc|Number=Sing	45	nmod	45:nmod	SpaceAfter=No|Entity=NOCOREF:Gen)NOCOREF:Gen)CESSCASTP20011002168c22)
# 50	.	.	PUNCT	fp	PunctType=Peri	20	punct	20:punct	_
#
#
# # sent_id = CESS-CAST-P-20011002-168-s5
# # text = Una de las mujeres arrastra por el suelo de baldosas una silla metálica y el ensordecedor ruido ya provoca una sensación de angustia.
# 1	Una	uno	PRON	pi0fs000	Gender=Fem|Number=Sing|PronType=Ind	5	nsubj	5:nsubj	ArgTem=arg0:agt|Entity=(NOCOREF:Gen--1-gstype:gen
# 2	de	de	ADP	sps00	_	4	case	4:case	_
# 3	las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	4	det	4:det	Entity=(CESSCASTP20011002168c21--2-CorefType:ident,gstype:gen
# 4	mujeres	mujer	NOUN	ncfp000	Gender=Fem|Number=Plur	1	nmod	1:nmod	Entity=CESSCASTP20011002168c21)NOCOREF:Gen)
# 5	arrastra	arrastrar	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	0:root	_
# 6	por	por	ADP	sps00	_	8	case	8:case	_
# 7	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	8	det	8:det	Entity=(CESSCASTP20011002168c7--2-gstype:gen,HomoDD
# 8	suelo	suelo	NOUN	ncms000	Gender=Masc|Number=Sing	5	obl	5:obl	ArgTem=argM:loc
# 9	de	de	ADP	sps00	_	10	case	10:case	_
# 10	baldosas	baldosa	NOUN	ncfp000	Gender=Fem|Number=Plur	8	nmod	8:nmod	Entity=CESSCASTP20011002168c7)
# 11	una	uno	DET	di0fs0	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	12	det	12:det	Entity=(NOCOREF:Gen--2-gstype:gen
# 12	silla	silla	NOUN	ncfs000	Gender=Fem|Number=Sing	5	obj	5:obj	ArgTem=arg1:pat
# 13	metálica	metálico	ADJ	aq0fs0	Gender=Fem|Number=Sing	12	amod	12:amod	Entity=NOCOREF:Gen)
# 14	y	y	CCONJ	cc	_	19	cc	19:cc	_
# 15	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	17	det	17:det	Entity=(NOCOREF:Gen--3-gstype:gen,HomoDD
# 16	ensordecedor	ensordecedor	ADJ	aq0ms0	Gender=Masc|Number=Sing	17	amod	17:amod	_
# 17	ruido	ruido	NOUN	ncms000	Gender=Masc|Number=Sing	19	nsubj	19:nsubj	ArgTem=arg0:cau|Entity=NOCOREF:Gen)
# 18	ya	ya	ADV	rg	_	19	advmod	19:advmod	ArgTem=argM:tmp
# 19	provoca	provocar	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	5	conj	5:conj	_
# 20	una	uno	DET	di0fs0	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	21	det	21:det	Entity=(NOCOREF:Gen--2-gstype:gen
# 21	sensación	sensación	NOUN	ncfs000	Gender=Fem|Number=Sing	19	obj	19:obj	ArgTem=arg1:tem
# 22	de	de	ADP	sps00	_	23	case	23:case	_
# 23	angustia	angustia	NOUN	ncfs000	Gender=Fem|Number=Sing	21	nmod	21:nmod	SpaceAfter=No|ArgTem=arg2:atr|Entity=NOCOREF:Gen)
# 24	.	.	PUNCT	fp	PunctType=Peri	5	punct	5:punct	_
#
#
# # sent_id = CESS-CAST-P-20011002-168-s6
# # text = Otra mujer tropieza y cae al suelo.
# 1	Otra	otro	DET	di0fs0	Gender=Fem|Number=Sing|PronType=Ind	2	det	2:det	Entity=(CESSCASTP20011002168c3--2-gstype:gen
# 2	mujer	mujer	NOUN	ncfs000	Gender=Fem|Number=Sing	3	nsubj	3:nsubj	ArgTem=arg0:agt|Entity=CESSCASTP20011002168c3)
# 3	tropieza	tropezar	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	0:root	_
# 4	y	y	CCONJ	cc	_	5	cc	5:cc	_
# 4.1	_	_	PRON	p	_	_	_	5:nsubj	ArgTem=arg1:tem|Entity=(CESSCASTP20011002168c3--1-CorefType:ident,gstype:gen)
# 5	cae	caer	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	3	conj	3:conj	_
# 6-7	al	_	_	_	_	_	_	_	_
# 6	a	a	ADP	spcms	_	8	case	8:case	_
# 7	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	8	det	8:det	_
# 8	suelo	suelo	NOUN	ncms000	Gender=Masc|Number=Sing	5	obl	5:obl	SpaceAfter=No|ArgTem=arg2:loc|Entity=(CESSCASTP20011002168c7--1-CorefType:ident,gstype:gen,HomoDD)
# 9	.	.	PUNCT	fp	PunctType=Peri	3	punct	3:punct	_
#
#
# # sent_id = CESS-CAST-P-20011002-168-s7
# # text = El espeso líquido del vino color sangre que consumen se derrama, una copa se rompe y la sangre de los cortes producidos con el cristal se confunde con el vino por el suelo.
# 1	El	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	3	det	3:det	Entity=(CESSCASTP20011002168c4--3-CorefType:ident,gstype:gen,HomoDD
# 2	espeso	espeso	ADJ	aq0ms0	Gender=Masc|Number=Sing	3	amod	3:amod	_
# 3	líquido	líquido	NOUN	ncms000	Gender=Masc|Number=Sing	12	nsubj	12:nsubj	ArgTem=arg1:tem
# 4-5	del	_	_	_	_	_	_	_	_
# 4	de	de	ADP	spcms	_	6	case	6:case	_
# 5	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	6	det	6:det	_
# 6	vino	vino	NOUN	ncms000	Gender=Masc|Number=Sing	3	nmod	3:nmod	Entity=(CESSCASTP20011002168c6--1-gstype:gen,HomoDD
# 7	color	color	NOUN	ncms000	Gender=Masc|Number=Sing	6	appos	6:appos	Entity=(NOCOREF:Gen--1-gstype:gen
# 8	sangre	sangre	NOUN	ncfs000	Gender=Fem|Number=Sing	7	nmod	7:nmod	Entity=NOCOREF:Gen)CESSCASTP20011002168c6)
# 9	que	que	PRON	pr0cn000	PronType=Rel	10	obj	10:obj	ArgTem=arg1:pat|Entity=(CESSCASTP20011002168c4--1-CorefType:ident,gstype:gen)
# 9.1	_	_	PRON	p	_	_	_	10:nsubj	ArgTem=arg0:agt|Entity=(CESSCASTP20011002168c5--1-CorefType:ident,gstype:gen)
# 10	consumen	consumar	VERB	vmsp3p0	Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	3	acl	3:acl	Entity=CESSCASTP20011002168c4)
# 11	se	él	PRON	p0300000	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	12	expl:pv	12:expl:pv	_
# 12	derrama	derramar	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	0:root	SpaceAfter=No
# 13	,	,	PUNCT	fc	PunctType=Comm	17	punct	17:punct	_
# 14	una	uno	DET	di0fs0	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	15	det	15:det	Entity=(NOCOREF:Gen--2-gstype:gen
# 15	copa	copa	NOUN	ncfs000	Gender=Fem|Number=Sing	17	nsubj	17:nsubj	ArgTem=arg1:tem|Entity=NOCOREF:Gen)
# 16	se	él	PRON	p0300000	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	17	expl:pv	17:expl:pv	_
# 17	rompe	romper	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	12	advcl	12:advcl	_
# 18	y	y	CCONJ	cc	_	29	cc	29:cc	_
# 19	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	20	det	20:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 20	sangre	sangre	NOUN	ncfs000	Gender=Fem|Number=Sing	29	nsubj	29:nsubj	ArgTem=arg1:pat
# 21	de	de	ADP	sps00	_	23	case	23:case	_
# 22	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	23	det	23:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 23	cortes	corte	NOUN	ncmp000	Gender=Masc|Number=Plur	20	nmod	20:nmod	_
# 24	producidos	producido	ADJ	aq0mpp	Gender=Masc|Number=Plur|VerbForm=Part	23	amod	23:amod	_
# 25	con	con	ADP	sps00	_	27	case	27:case	_
# 26	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	27	det	27:det	Entity=(NOCOREF:Gen--2-gstype:gen
# 27	cristal	cristal	NOUN	ncms000	Gender=Masc|Number=Sing	24	obl:arg	24:obl:arg	ArgTem=arg0:agt|Entity=NOCOREF:Gen)NOCOREF:Gen)NOCOREF:Gen)
# 28	se	él	PRON	p0000000	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	29	expl:pass	29:expl:pass	_
# 29	confunde	confundir	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	12	conj	12:conj	_
# 30	con	con	ADP	sps00	_	32	case	32:case	_
# 31	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	32	det	32:det	Entity=(CESSCASTP20011002168c6--2-CorefType:ident,gstype:gen
# 32	vino	vino	NOUN	ncms000	Gender=Masc|Number=Sing	29	obl:arg	29:obl:arg	ArgTem=arg2:tem|Entity=CESSCASTP20011002168c6)
# 33	por	por	ADP	sps00	_	35	case	35:case	_
# 34	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	35	det	35:det	Entity=(CESSCASTP20011002168c7--2-CorefType:ident,gstype:gen,HomoDD
# 35	suelo	suelo	NOUN	ncms000	Gender=Masc|Number=Sing	29	obl	29:obl	SpaceAfter=No|ArgTem=argM:loc|Entity=CESSCASTP20011002168c7)
# 36	.	.	PUNCT	fp	PunctType=Peri	12	punct	12:punct	_
#
#
# # sent_id = CESS-CAST-P-20011002-168-s8
# # text = Si a eso añadimos las imágenes intercaladas de unos niños, a uno de los cuales le falta un ojo, acosando con sus perros a una vaca que está inmovilizada en la ciénaga ponzoñosa, y la contemplación que de la decadente escena del fin de fiesta junto a la piscina hacen otras niñas, hijas de los anfitriones del festejo etílico, tendremos la medida justa de lo que intenta y provoca Lucrecia Martel con su debut: crear una sensación permanente de malestar, de enfermizo y a la vez realista agobio cotidiano, a través de la cual se cuelan los retazos dramáticos de la existencia de dos familias emparentadas.
# 1	Si	si	SCONJ	cs	_	4	mark	4:mark	_
# 2	a	a	ADP	sps00	_	3	case	3:case	_
# 3	eso	ese	PRON	pd0ns000	Number=Sing|PronType=Dem	4	obj	4:obj	ArgTem=arg2:tem|Entity=(NOCOREF:Gen--1-gstype:gen)
# 3.1	_	_	PRON	p	_	_	_	4:nsubj	ArgTem=arg0:agt|Entity=(CESSCASTP20011002168c14--1-CorefType:ident)
# 4	añadimos	añadir	VERB	vmip1p0	Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin	67	advcl	67:advcl	_
# 5	las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	6	det	6:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 6	imágenes	imagen	NOUN	ncfp000	Gender=Fem|Number=Plur	4	obj	4:obj	ArgTem=arg1:pat
# 7	intercaladas	intercalado	ADJ	aq0fpp	Gender=Fem|Number=Plur|VerbForm=Part	6	amod	6:amod	_
# 8	de	de	ADP	sps00	_	10	case	10:case	_
# 9	unos	uno	DET	di0mp0	Definite=Ind|Gender=Masc|Number=Plur|PronType=Art	10	det	10:det	Entity=(CESSCASTP20011002168c8--2-gstype:gen
# 10	niños	niño	NOUN	ncmp000	Gender=Masc|Number=Plur	6	nmod	6:nmod	SpaceAfter=No
# 11	,	,	PUNCT	fc	PunctType=Comm	18	punct	18:punct	_
# 12	a	a	ADP	sps00	_	13	case	13:case	_
# 13	uno	uno	PRON	pi0ms000	Gender=Masc|Number=Sing|PronType=Ind	18	obl:arg	18:obl:arg	ArgTem=arg2:exp|Entity=(CESSCASTP20011002168c9--1-gstype:gen
# 14	de	de	ADP	sps00	_	16	case	16:case	_
# 15	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	16	det	16:det	Entity=(CESSCASTP20011002168c8--2-CorefType:ident,gstype:gen
# 16	cuales	cual	PRON	pr0cp000	Number=Plur|PronType=Rel	13	nmod	13:nmod	Entity=CESSCASTP20011002168c8)CESSCASTP20011002168c9)
# 17	le	él	PRON	pp3csd00	Case=Dat|Number=Sing|Person=3|PronType=Prs	18	expl	18:expl	ArgTem=arg2:exp|Entity=(CESSCASTP20011002168c9--1-CorefType:ident,gstype:gen)
# 18	falta	faltar	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	10	acl	10:acl	_
# 19	un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	20	det	20:det	Entity=(NOCOREF:Gen--2-gstype:gen
# 20	ojo	ojo	NOUN	ncms000	Gender=Masc|Number=Sing	18	nsubj	18:nsubj	SpaceAfter=No|ArgTem=arg1:tem|Entity=NOCOREF:Gen)
# 21	,	,	PUNCT	fc	PunctType=Comm	18	punct	18:punct	_
# 22	acosando	acosar	VERB	vmg0000	VerbForm=Ger	10	acl	10:acl	_
# 23	con	con	ADP	sps00	_	25	case	25:case	_
# 24	sus	su	DET	dp3cp0	Number=Plur|Person=3|Poss=Yes|PronType=Prs	25	det	25:det	Entity=(NOCOREF:Gen--2-gstype:gen(CESSCASTP20011002168c8--1-CorefType:ident,gstype:gen)
# 25	perros	perro	NOUN	ncmp000	Gender=Masc|Number=Plur	22	obl	22:obl	ArgTem=argM:adv|Entity=NOCOREF:Gen)
# 26	a	a	ADP	sps00	_	28	case	28:case	_
# 27	una	uno	DET	di0fs0	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	28	det	28:det	Entity=(CESSCASTP20011002168c10--2-gstype:gen
# 28	vaca	vaca	NOUN	ncfs000	Gender=Fem|Number=Sing	22	obj	22:obj	ArgTem=arg1:pat
# 29	que	que	PRON	pr0cn000	PronType=Rel	31	nsubj	31:nsubj	ArgTem=arg1:tem|Entity=(CESSCASTP20011002168c10--1-CorefType:ident,gstype:gen)
# 30	está	estar	AUX	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	31	cop	31:cop	_
# 31	inmovilizada	inmovilizado	ADJ	aq0fsp	Gender=Fem|Number=Sing|VerbForm=Part	28	acl	28:acl	ArgTem=arg2:atr
# 32	en	en	ADP	sps00	_	34	case	34:case	_
# 33	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	34	det	34:det	Entity=(CESSCASTP20011002168c18--2-gstype:gen,HomoDD
# 34	ciénaga	ciénaga	NOUN	ncfs000	Gender=Fem|Number=Sing	31	obl	31:obl	ArgTem=argM:loc
# 35	ponzoñosa	ponzoñoso	ADJ	aq0fs0	Gender=Fem|Number=Sing	34	amod	34:amod	SpaceAfter=No|Entity=CESSCASTP20011002168c18)CESSCASTP20011002168c10)
# 36	,	,	PUNCT	fc	PunctType=Comm	39	punct	39:punct	Entity=CESSCASTP20011002168c8)
# 37	y	y	CCONJ	cc	_	39	cc	39:cc	_
# 38	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	39	det	39:det	Entity=(CESSCASTP20011002168c11--2-gstype:gen,HomoDD
# 39	contemplación	contemplación	NOUN	ncfs000	Gender=Fem|Number=Sing	10	conj	10:conj	ArgTem=arg1:pat
# 40	que	que	PRON	pr0cn000	PronType=Rel	54	obj	54:obj	ArgTem=arg1:tem|Entity=(CESSCASTP20011002168c11--1-CorefType:ident,gstype:gen)
# 41	de	de	ADP	sps00	_	44	case	44:case	_
# 42	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	44	det	44:det	Entity=(CESSCASTP20011002168c12--3-CorefType:ident,gstype:gen,HomoDD
# 43	decadente	decadente	ADJ	aq0cs0	Number=Sing	44	amod	44:amod	_
# 44	escena	escena	NOUN	ncfs000	Gender=Fem|Number=Sing	54	obl:arg	54:obl:arg	ArgTem=arg2:ein
# 45-46	del	_	_	_	_	_	_	_	_
# 45	de	de	ADP	spcms	_	47	case	47:case	_
# 46	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	47	det	47:det	_
# 47	fin	fin	NOUN	ncms000	Gender=Masc|Number=Sing	44	nmod	44:nmod	Entity=(NOCOREF:Gen--1-gstype:gen,HomoDD
# 48	de	de	ADP	sps00	_	49	case	49:case	_
# 49	fiesta	fiesta	NOUN	ncfs000	Gender=Fem|Number=Sing	47	nmod	47:nmod	Entity=NOCOREF:Gen)
# 50	junto	junto	ADJ	sps00	_	53	case	53:case	MWE=junto_a|MWEPOS=ADP
# 51	a	a	ADP	_	_	50	fixed	50:fixed	_
# 52	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	53	det	53:det	Entity=(CESSCASTP20011002168c22--2-CorefType:ident,gstype:gen
# 53	piscina	piscina	NOUN	ncfs000	Gender=Fem|Number=Sing	44	nmod	44:nmod	Entity=CESSCASTP20011002168c22)CESSCASTP20011002168c12)
# 54	hacen	hacer	VERB	vmip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	39	acl	39:acl	_
# 55	otras	otro	DET	di0fp0	Gender=Fem|Number=Plur|PronType=Ind	56	det	56:det	Entity=(CESSCASTP20011002168c23--2-gstype:gen
# 56	niñas	niña	NOUN	ncfp000	Gender=Fem|Number=Plur	54	nsubj	54:nsubj	SpaceAfter=No|ArgTem=arg0:cau
# 57	,	,	PUNCT	fc	PunctType=Comm	58	punct	58:punct	Entity=(CESSCASTP20011002168c23--2-CorefType:pred.definit,gstype:gen
# 58	hijas	hija	NOUN	ncfp000	Gender=Fem|Number=Plur	56	appos	56:appos	_
# 59	de	de	ADP	sps00	_	61	case	61:case	_
# 60	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	61	det	61:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 61	anfitriones	anfitrión	NOUN	ncmp000	Gender=Masc|Number=Plur	58	nmod	58:nmod	_
# 62-63	del	_	_	_	_	_	_	_	_
# 62	de	de	ADP	spcms	_	64	case	64:case	_
# 63	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	64	det	64:det	_
# 64	festejo	festejo	NOUN	ncms000	Gender=Masc|Number=Sing	61	nmod	61:nmod	Entity=(CESSCASTP20011002168c13--1-CorefType:ident,gstype:gen,HomoDD
# 65	etílico	etílico	ADJ	aq0ms0	Gender=Masc|Number=Sing	64	amod	64:amod	SpaceAfter=No|Entity=CESSCASTP20011002168c13)NOCOREF:Gen)CESSCASTP20011002168c23)CESSCASTP20011002168c23)CESSCASTP20011002168c11)NOCOREF:Gen)
# 66	,	,	PUNCT	fc	PunctType=Comm	4	punct	4:punct	_
# 66.1	_	_	PRON	p	_	_	_	67:nsubj	ArgTem=arg1:tem|Entity=(CESSCASTP20011002168c14--1-CorefType:ident)
# 67	tendremos	tener	VERB	vmif1p0	Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin	0	root	0:root	_
# 68	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	69	det	69:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 69	medida	medida	NOUN	ncfs000	Gender=Fem|Number=Sing	67	obj	67:obj	ArgTem=arg2:atr
# 70	justa	justo	ADJ	aq0fs0	Gender=Fem|Number=Sing	69	amod	69:amod	_
# 71	de	de	ADP	sps00	_	74	mark	74:mark	_
# 72	lo	él	PRON	da0ns0	Case=Acc|Definite=Def|Gender=Masc|Number=Sing|Person=3|PrepCase=Npr|PronType=Prs	74	det	74:det	Entity=(NOCOREF:Gen--4-gstype:gen
# 73	que	que	PRON	pr0cn000	PronType=Rel	74	obj	74:obj	ArgTem=arg1:pat
# 73.1	_	_	PRON	p	_	_	_	74:nsubj	ArgTem=arg0:agt|Entity=(CESSCASTP20011002168c15-person-1-CorefType:ident,gstype:spec)
# 74	intenta	intentar	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	69	acl	69:acl	ArgTem=arg1:pat
# 75	y	y	CCONJ	cc	_	76	cc	76:cc	_
# 76	provoca	provocar	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	74	conj	74:conj	_
# 77	Lucrecia	Lucrecia	PROPN	np00000	_	76	nsubj	76:nsubj	MWE=Lucrecia_Martel|MWEPOS=PROPN|ArgTem=arg0:cau|Entity=(CESSCASTP20011002168c15-person-1-CorefType:ident,gstype:spec
# 78	Martel	Martel	PROPN	_	_	77	flat	77:flat	Entity=CESSCASTP20011002168c15)
# 79	con	con	ADP	sps00	_	81	case	81:case	_
# 80	su	su	DET	dp3cs0	Number=Sing|Person=3|Poss=Yes|PronType=Prs	81	det	81:det	Entity=(CESSCASTP20011002168c1-other-2-CorefType:ident,gstype:spec(CESSCASTP20011002168c15-person-1-CorefType:ident,gstype:spec)
# 81	debut	debut	NOUN	ncms000	Gender=Masc|Number=Sing	74	obl	74:obl	SpaceAfter=No|ArgTem=argM:adv|Entity=CESSCASTP20011002168c1)
# 82	:	:	PUNCT	fd	PunctType=Colo	83	punct	83:punct	_
# 83	crear	crear	VERB	vmn0000	VerbForm=Inf	74	advcl	74:advcl	_
# 84	una	uno	DET	di0fs0	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	85	det	85:det	Entity=(CESSCASTP20011002168c16--2-gstype:gen
# 85	sensación	sensación	NOUN	ncfs000	Gender=Fem|Number=Sing	83	obj	83:obj	ArgTem=arg1:pat
# 86	permanente	permanente	ADJ	aq0cs0	Number=Sing	85	amod	85:amod	_
# 87	de	de	ADP	sps00	_	88	case	88:case	_
# 88	malestar	malestar	NOUN	ncms000	Gender=Masc|Number=Sing	85	nmod	85:nmod	SpaceAfter=No|ArgTem=arg2:atr|Entity=(NOCOREF:Gen--1-gstype:gen)
# 89	,	,	PUNCT	fc	PunctType=Comm	97	punct	97:punct	_
# 90	de	de	ADP	sps00	_	97	case	97:case	_
# 91	enfermizo	enfermizo	ADJ	aq0ms0	Gender=Masc|Number=Sing	97	amod	97:amod	Entity=(NOCOREF:Gen--7-gstype:gen
# 92	y	y	CCONJ	cc	_	96	cc	96:cc	_
# 93	a	a	ADP	rg	_	96	advmod	96:advmod	MWE=a_la_vez|MWEPOS=ADV
# 94	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	93	fixed	93:fixed	_
# 95	vez	vez	NOUN	_	_	93	fixed	93:fixed	_
# 96	realista	realista	ADJ	aq0cs0	Number=Sing	91	conj	91:conj	_
# 97	agobio	agobio	NOUN	ncms000	Gender=Masc|Number=Sing	88	conj	88:conj	_
# 98	cotidiano	cotidiano	ADJ	aq0ms0	Gender=Masc|Number=Sing	97	amod	97:amod	SpaceAfter=No|Entity=NOCOREF:Gen)
# 99	,	,	PUNCT	fc	PunctType=Comm	106	punct	106:punct	_
# 100	a	a	ADP	sps00	_	104	case	104:case	MWE=a_través_de|MWEPOS=ADP
# 101	través	través	NOUN	_	_	100	fixed	100:fixed	_
# 102	de	de	ADP	_	_	100	fixed	100:fixed	_
# 103	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	104	det	104:det	Entity=(CESSCASTP20011002168c16--2-CorefType:ident,gstype:gen
# 104	cual	cual	PRON	pr0cs000	Number=Sing|PronType=Rel	106	obl	106:obl	ArgTem=arg2:loc|Entity=CESSCASTP20011002168c16)
# 105	se	él	PRON	p0300000	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	106	expl:pv	106:expl:pv	_
# 106	cuelan	colar	VERB	vmip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	85	acl	85:acl	_
# 107	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	108	det	108:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 108	retazos	retazo	NOUN	ncmp000	Gender=Masc|Number=Plur	106	nsubj	106:nsubj	ArgTem=arg1:tem
# 109	dramáticos	dramático	ADJ	aq0mp0	Gender=Masc|Number=Plur	108	amod	108:amod	_
# 110	de	de	ADP	sps00	_	112	case	112:case	_
# 111	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	112	det	112:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 112	existencia	existencia	NOUN	ncfs000	Gender=Fem|Number=Sing	108	nmod	108:nmod	_
# 113	de	de	ADP	sps00	_	115	case	115:case	_
# 114	dos	dos	NUM	dn0cp0	Number=Plur|NumForm=Word|NumType=Card	115	nummod	115:nummod	Entity=(NOCOREF:Gen--2-gstype:gen
# 115	familias	familia	NOUN	ncfp000	Gender=Fem|Number=Plur	112	nmod	112:nmod	ArgTem=arg1:tem
# 116	emparentadas	emparentado	ADJ	aq0fpp	Gender=Fem|Number=Plur|VerbForm=Part	115	amod	115:amod	SpaceAfter=No|Entity=NOCOREF:Gen)NOCOREF:Gen)NOCOREF:Gen)CESSCASTP20011002168c16)NOCOREF:Gen)NOCOREF:Gen)
# 117	.	.	PUNCT	fp	PunctType=Peri	67	punct	67:punct	_
#
#
# # sent_id = CESS-CAST-P-20011002-168-s9
# # text = Notable y original película, pues, que hace de los elementos físicos - - las torrenciales lluvias que caen de vez en cuando, la tierra reseca por el sol del caluroso verano en el norte de Argentina, la atmósfera pútrida de la ciénaga que rodea la casa, las referencias a la mandrágora como misteriosa planta sedante - - y de los gestos - - impagables las expresiones de todos los actores, algunos de los cuales deben interpretar personajes que parecen estar siempre en duermevela - -, materia de encomiable estilo.
# 1	Notable	notable	ADJ	aq0cs0	Number=Sing	4	amod	4:amod	Entity=(CESSCASTP20011002168c1-other-4-CorefType:pred.indefinit,gstype:spec
# 2	y	y	CCONJ	cc	_	3	cc	3:cc	_
# 3	original	original	ADJ	aq0cs0	Number=Sing	1	conj	1:conj	_
# 4	película	película	NOUN	ncfs000	Gender=Fem|Number=Sing	9	obj	9:obj	SpaceAfter=No|Entity=CESSCASTP20011002168c1)
# 5	,	,	PUNCT	fc	PunctType=Comm	6	punct	6:punct	_
# 6	pues	pues	ADV	rg	_	9	advmod	9:advmod	SpaceAfter=No
# 7	,	,	PUNCT	fc	PunctType=Comm	6	punct	6:punct	_
# 8	que	que	PRON	pr0cn000	PronType=Rel	9	nsubj	9:nsubj	ArgTem=arg0:cau|Entity=(CESSCASTP20011002168c1-other-1-CorefType:ident,gstype:spec)
# 9	hace	hacer	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	0:root	_
# 10	de	de	ADP	sps00	_	12	case	12:case	_
# 11	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	12	det	12:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 12	elementos	elemento	NOUN	ncmp000	Gender=Masc|Number=Plur	9	obl:arg	9:obl:arg	ArgTem=arg2:ein
# 13	físicos	físico	ADJ	aq0mp0	Gender=Masc|Number=Plur	12	amod	12:amod	_
# 14	-	-	PUNCT	fg	PunctType=Dash	18	punct	18:punct	_
# 15	-	-	PUNCT	fg	PunctType=Dash	18	punct	18:punct	_
# 16	las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	18	det	18:det	Entity=(CESSCASTP20011002168c17--3-gstype:gen,HomoDD
# 17	torrenciales	torrencial	ADJ	aq0cp0	Number=Plur	18	amod	18:amod	_
# 18	lluvias	lluvia	NOUN	ncfp000	Gender=Fem|Number=Plur	12	appos	12:appos	_
# 19	que	que	PRON	pr0cn000	PronType=Rel	20	nsubj	20:nsubj	ArgTem=arg1:tem|Entity=(CESSCASTP20011002168c17--1-CorefType:ident,gstype:gen)
# 20	caen	caer	VERB	vmip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	18	acl	18:acl	_
# 21	de	de	ADP	rg	_	20	advmod	20:advmod	MWE=de_vez_en_cuando|MWEPOS=ADV|ArgTem=argM:tmp
# 22	vez	vez	NOUN	_	_	21	fixed	21:fixed	_
# 23	en	en	ADP	_	_	21	fixed	21:fixed	_
# 24	cuando	cuando	ADV	_	PronType=Rel	21	fixed	21:fixed	SpaceAfter=No|Entity=CESSCASTP20011002168c17)
# 25	,	,	PUNCT	fc	PunctType=Comm	18	punct	18:punct	_
# 26	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	27	det	27:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 27	tierra	tierra	NOUN	ncfs000	Gender=Fem|Number=Sing	18	appos	18:appos	_
# 28	reseca	reseco	ADJ	aq0fs0	Gender=Fem|Number=Sing	27	amod	27:amod	_
# 29	por	por	ADP	sps00	_	31	case	31:case	_
# 30	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	31	det	31:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 31	sol	sol	NOUN	ncms000	Gender=Masc|Number=Sing	28	nmod	28:nmod	_
# 32-33	del	_	_	_	_	_	_	_	_
# 32	de	de	ADP	spcms	_	35	case	35:case	_
# 33	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	35	det	35:det	_
# 34	caluroso	caluroso	ADJ	aq0ms0	Gender=Masc|Number=Sing	35	amod	35:amod	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 35	verano	verano	NOUN	ncms000	Gender=Masc|Number=Sing	31	nmod	31:nmod	Entity=NOCOREF:Gen)NOCOREF:Gen)
# 36	en	en	ADP	sps00	_	38	case	38:case	_
# 37	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	38	det	38:det	Entity=(NOCOREF:Spec.location-place-2-gstype:spec
# 38	norte	norte	NOUN	ncms000	Gender=Masc|Number=Sing	27	nmod	27:nmod	_
# 39	de	de	ADP	sps00	_	40	case	40:case	_
# 40	Argentina	Argentina	PROPN	np00000	_	38	nmod	38:nmod	SpaceAfter=No|Entity=(NOCOREF:Spec.location-place-1-gstype:spec)NOCOREF:Spec.location)NOCOREF:Gen)
# 41	,	,	PUNCT	fc	PunctType=Comm	18	punct	18:punct	_
# 42	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	43	det	43:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 43	atmósfera	atmósfera	NOUN	ncfs000	Gender=Fem|Number=Sing	18	appos	18:appos	_
# 44	pútrida	pútrido	ADJ	aq0fs0	Gender=Fem|Number=Sing	43	amod	43:amod	_
# 45	de	de	ADP	sps00	_	47	case	47:case	_
# 46	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	47	det	47:det	Entity=(CESSCASTP20011002168c18--2-CorefType:ident,gstype:gen,HomoDD
# 47	ciénaga	ciénaga	NOUN	ncfs000	Gender=Fem|Number=Sing	43	nmod	43:nmod	_
# 48	que	que	PRON	pr0cn000	PronType=Rel	49	nsubj	49:nsubj	ArgTem=arg0:agt|Entity=(CESSCASTP20011002168c18--1-CorefType:ident,gstype:gen)
# 49	rodea	rodear	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	47	acl	47:acl	_
# 50	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	51	det	51:det	Entity=(NOCOREF:Gen--2-gstype:gen
# 51	casa	casa	NOUN	ncfs000	Gender=Fem|Number=Sing	49	obj	49:obj	SpaceAfter=No|ArgTem=arg1:pat|Entity=NOCOREF:Gen)CESSCASTP20011002168c18)NOCOREF:Gen)
# 52	,	,	PUNCT	fc	PunctType=Comm	18	punct	18:punct	_
# 53	las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	54	det	54:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 54	referencias	referencia	NOUN	ncfp000	Gender=Fem|Number=Plur	18	appos	18:appos	_
# 55	a	a	ADP	sps00	_	57	case	57:case	_
# 56	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	57	det	57:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 57	mandrágora	mandrágora	NOUN	ncfs000	Gender=Fem|Number=Sing	54	nmod	54:nmod	ArgTem=arg1:pat
# 58	como	como	SCONJ	cs	_	60	mark	60:mark	_
# 59	misteriosa	misterioso	ADJ	aq0fs0	Gender=Fem|Number=Sing	60	amod	60:amod	_
# 60	planta	planta	NOUN	ncfs000	Gender=Fem|Number=Sing	57	nmod	57:nmod	_
# 61	sedante	sedante	ADJ	aq0cs0	Number=Sing	60	amod	60:amod	Entity=NOCOREF:Gen)NOCOREF:Gen)
# 62	-	-	PUNCT	fg	PunctType=Dash	18	punct	18:punct	_
# 63	-	-	PUNCT	fg	PunctType=Dash	18	punct	18:punct	Entity=NOCOREF:Gen)
# 64	y	y	CCONJ	cc	_	67	cc	67:cc	_
# 65	de	de	ADP	sps00	_	67	case	67:case	_
# ...
# 26	Arzalluz	Arzalluz	PROPN	np00000	_	25	nsubj	25:nsubj	SpaceAfter=No|ArgTem=arg0:agt|Entity=(CESSCASTP2002080117c2-person-1-CorefType:ident,gstype:spec
# 27	,	,	PUNCT	fc	PunctType=Comm	30	punct	30:punct	_
# 28	que	que	PRON	pr0cn000	PronType=Rel	30	nsubj	30:nsubj	ArgTem=arg0:agt|Entity=(CESSCASTP2002080117c2-person-1-CorefType:ident,gstype:spec)
# 29	también	también	ADV	rg	_	30	advmod	30:advmod	_
# 30	criticó	criticar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	26	acl	26:acl	_
# 31-32	al	_	_	_	_	_	_	_	_
# 31	a	a	ADP	spcms	_	33	case	33:case	_
# 32	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	33	det	33:det	_
# 33	director	director	NOUN	ncms000	Gender=Masc|Number=Sing	30	obj	30:obj	ArgTem=arg1:pat|Entity=(CESSCASTP2002080117c18-person-1-gstype:spec
# 34-35	del	_	_	_	_	_	_	_	_
# 34	de	de	ADP	spcms	_	36	case	36:case	_
# 35	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	36	det	36:det	_
# 36	Euskobarómetro	Euskobarómetro	PROPN	np00000	_	33	nmod	33:nmod	SpaceAfter=No|Entity=(NOCOREF:Spec.organization-organization-1-gstype:spec)
# 37	,	,	PUNCT	fc	PunctType=Comm	38	punct	38:punct	Entity=(CESSCASTP2002080117c18-person-2-CorefType:pred.definit,gstype:spec
# 38	Francisco	Francisco	PROPN	np00000	_	33	appos	33:appos	MWE=Francisco_Llera|MWEPOS=PROPN
# 39	Llera	Llera	PROPN	_	_	38	flat	38:flat	SpaceAfter=No
# 40	,	,	PUNCT	fc	PunctType=Comm	38	punct	38:punct	Entity=CESSCASTP2002080117c18)
# 41	que	que	PRON	pr0cn000	PronType=Rel	42	nsubj	42:nsubj	ArgTem=arg0:agt|Entity=(CESSCASTP2002080117c18-person-1-CorefType:ident,gstype:spec)
# 42	anunció	anunciar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	33	acl	33:acl	_
# 43	su	su	DET	dp3cs0	Number=Sing|Person=3|Poss=Yes|PronType=Prs	44	det	44:det	ArgTem=arg0:agt|Entity=(NOCOREF:Gen--2-gstype:gen(CESSCASTP2002080117c18-person-1-CorefType:ident,gstype:spec)
# 44	marcha	marcha	NOUN	ncfs000	Gender=Fem|Number=Sing	42	obj	42:obj	ArgTem=arg1:pat
# 45	de	de	ADP	sps00	_	46	case	46:case	_
# 46	Euskadi	Euskadi	PROPN	np00000	_	44	nmod	44:nmod	SpaceAfter=No|ArgTem=arg3:ori|Entity=(NOCOREF:Spec.location-place-1-gstype:spec)NOCOREF:Gen)CESSCASTP2002080117c18)
# 47	:	:	PUNCT	fd	PunctType=Colo	50	punct	50:punct	_
# 48	"	"	PUNCT	fe	PunctType=Quot	50	punct	50:punct	SpaceAfter=No
# 48.1	_	_	PRON	p	_	_	_	50:nsubj	ArgTem=arg0:agt|Entity=(CESSCASTP2002080117c18-person-1-CorefType:ident,gstype:spec)
# 49	se	él	PRON	p0300000	Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	50	expl:pv	50:expl:pv	_
# 50	va	ir	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	30	advcl	30:advcl	_
# 51	con	con	ADP	sps00	_	53	case	53:case	_
# 52	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	53	det	53:det	Entity=(CESSCASTP2002080117c19--2-gstype:gen,HomoDD
# 53	chollo	chollo	NOUN	ncms000	Gender=Masc|Number=Sing	50	obl	50:obl	ArgTem=argM:adv
# 54	que	que	PRON	pr0cn000	PronType=Rel	57	obj	57:obj	ArgTem=arg1:pat|Entity=(CESSCASTP2002080117c19--1-CorefType:ident,gstype:gen)
# 55	le	él	PRON	pp3csd00	Case=Dat|Number=Sing|Person=3|PronType=Prs	57	obl:arg	57:obl:arg	ArgTem=arg2:ben|Entity=(CESSCASTP2002080117c18-person-1-CorefType:ident,gstype:spec)
# 56	han	haber	AUX	vaip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	57	aux	57:aux	_
# 57	dado	dar	VERB	vmp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	53	acl	53:acl	_
# 58	(	(	PUNCT	fpa	PunctSide=Ini|PunctType=Brck	60	punct	60:punct	SpaceAfter=No
# 59	una	uno	DET	di0fs0	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	60	det	60:det	_
# 60	cátedra	cátedra	NOUN	ncfs000	Gender=Fem|Number=Sing	53	appos	53:appos	_
# 61	en	en	ADP	sps00	_	62	case	62:case	_
# 62	Nueva	Nueva	PROPN	np00000	_	60	nmod	60:nmod	MWE=Nueva_York|MWEPOS=PROPN|Entity=(NOCOREF:Spec.location-place-1-gstype:spec
# 63	York	York	PROPN	_	_	62	flat	62:flat	SpaceAfter=No|Entity=NOCOREF:Spec.location)
# 64	)	)	PUNCT	fpt	PunctSide=Fin|PunctType=Brck	60	punct	60:punct	SpaceAfter=No|Entity=CESSCASTP2002080117c19)
# 65	,	,	PUNCT	fc	PunctType=Comm	71	punct	71:punct	_
# 66	como	como	ADP	sps00	_	71	mark	71:mark	_
# 67	si	si	SCONJ	cs	_	71	mark	71:mark	_
# 68	se	él	PRON	p0000000	Case=Acc,Dat|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	71	expl:pass	71:expl:pass	_
# 69	le	él	PRON	pp30sa00	Case=Dat|Number=Sing|Person=3|PronType=Prs	71	obl:arg	71:obl:arg	ArgTem=arg1:pat|Entity=(CESSCASTP2002080117c18-person-1-CorefType:ident,gstype:spec)
# 70	hubiéramos	haber	AUX	vasi1p0	Mood=Sub|Number=Plur|Person=1|Tense=Imp|VerbForm=Fin	71	aux	71:aux	_
# 71	echado	echar	VERB	vmp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	50	advcl	50:advcl	SpaceAfter=No|ArgTem=argM:adv
# 72	"	"	PUNCT	fe	PunctType=Quot	50	punct	50:punct	SpaceAfter=No|Entity=CESSCASTP2002080117c2)
# 73	.	.	PUNCT	fp	PunctType=Peri	25	punct	25:punct	_
#
#
# # sent_id = CESS-CAST-P-20020801-17-s16
# # text = El líder peneuvista lee un artículo de Aznar "nostálgico del franquismo".
# 1	El	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	2	det	2:det	Entity=(CESSCASTP2002080117c2-person-2-CorefType:ident,gstype:spec
# 2	líder	líder	NOUN	nccs000	Number=Sing	4	nsubj	4:nsubj	ArgTem=arg0:agt
# 3	peneuvista	peneuvista	ADJ	aq0cs0	Number=Sing	2	amod	2:amod	Entity=CESSCASTP2002080117c2)
# 4	lee	leer	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	0:root	_
# 5	un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	6	det	6:det	Entity=(NOCOREF:Gen--2-gstype:gen
# 6	artículo	artículo	NOUN	ncms000	Gender=Masc|Number=Sing	4	obj	4:obj	ArgTem=arg1:pat
# 7	de	de	ADP	sps00	_	8	case	8:case	_
# 8	Aznar	Aznar	PROPN	np00000	_	6	nmod	6:nmod	Entity=(CESSCASTP2002080117c21-person-1-gstype:spec)
# 9	"	"	PUNCT	fe	PunctType=Quot	10	punct	10:punct	SpaceAfter=No
# 10	nostálgico	nostálgico	ADJ	aq0ms0	Gender=Masc|Number=Sing	6	amod	6:amod	_
# 11-12	del	_	_	_	_	_	_	_	_
# 11	de	de	ADP	spcms	_	13	case	13:case	_
# 12	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	13	det	13:det	_
# 13	franquismo	franquismo	NOUN	ncms000	Gender=Masc|Number=Sing	10	nmod	10:nmod	SpaceAfter=No|Entity=(CESSCASTP2002080117c20--1-CorefType:ident,gstype:gen,HomoDD)
# 14	"	"	PUNCT	fe	PunctType=Quot	10	punct	10:punct	SpaceAfter=No|Entity=NOCOREF:Gen)
# 15	.	.	PUNCT	fp	PunctType=Peri	4	punct	4:punct	_
#
#
# # sent_id = CESS-CAST-P-20020801-17-s17
# # text = Arzalluz recuperó ayer la hemeroteca para "retratar" a Aznar como "nostálgico del régimen franquista".
# 1	Arzalluz	Arzalluz	PROPN	np00000	_	2	nsubj	2:nsubj	ArgTem=arg0:agt|Entity=(CESSCASTP2002080117c2-person-1-CorefType:ident,gstype:spec)
# 2	recuperó	recuperar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 3	ayer	ayer	ADV	rg	_	2	advmod	2:advmod	ArgTem=argM:tmp
# 4	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	5	det	5:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 5	hemeroteca	hemeroteca	NOUN	ncfs000	Gender=Fem|Number=Sing	2	obj	2:obj	ArgTem=arg1:pat|Entity=NOCOREF:Gen)
# 6	para	para	ADP	sps00	_	8	mark	8:mark	_
# 7	"	"	PUNCT	fe	PunctType=Quot	8	punct	8:punct	SpaceAfter=No
# 8	retratar	retratar	VERB	vmn0000	VerbForm=Inf	2	advcl	2:advcl	SpaceAfter=No|ArgTem=argM:fin
# 9	"	"	PUNCT	fe	PunctType=Quot	8	punct	8:punct	_
# 10	a	a	ADP	sps00	_	11	case	11:case	_
# 11	Aznar	Aznar	PROPN	np00000	_	8	obj	8:obj	ArgTem=arg1:pat|Entity=(CESSCASTP2002080117c21-person-1-CorefType:ident,gstype:spec)
# 12	como	como	ADP	sps00	_	14	case	14:case	_
# 13	"	"	PUNCT	fe	PunctType=Quot	14	punct	14:punct	SpaceAfter=No
# 14	nostálgico	nostálgico	NOUN	ncms000	Gender=Masc|Number=Sing	8	obl:arg	8:obl:arg	ArgTem=argM:atr
# 15-16	del	_	_	_	_	_	_	_	_
# 15	de	de	ADP	spcms	_	17	case	17:case	_
# 16	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	17	det	17:det	_
# 17	régimen	régimen	NOUN	ncms000	Gender=Masc|Number=Sing	14	nmod	14:nmod	Entity=(CESSCASTP2002080117c20--1-CorefType:ident,gstype:gen,HomoDD
# 18	franquista	franquista	ADJ	aq0cs0	Number=Sing	17	amod	17:amod	SpaceAfter=No|Entity=CESSCASTP2002080117c20)
# 19	"	"	PUNCT	fe	PunctType=Quot	14	punct	14:punct	SpaceAfter=No
# 20	.	.	PUNCT	fp	PunctType=Peri	2	punct	2:punct	_
#
#
# # sent_id = CESS-CAST-P-20020801-17-s18
# # text = Citó un texto del presidente en el diario Nueva Rioja del 9 de marzo de 1979.
# 0.1	_	_	PRON	p	_	_	_	1:nsubj	ArgTem=arg0:agt|Entity=(CESSCASTP2002080117c2-person-1-CorefType:ident,gstype:spec)
# 1	Citó	citar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 2	un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	3	det	3:det	Entity=(CESSCASTP2002080117c22--2-gstype:gen
# 3	texto	texto	NOUN	ncms000	Gender=Masc|Number=Sing	1	obj	1:obj	ArgTem=arg1:pat
# 4-5	del	_	_	_	_	_	_	_	_
# 4	de	de	ADP	spcms	_	6	case	6:case	_
# 5	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	6	det	6:det	_
# 6	presidente	presidente	NOUN	ncms000	Gender=Masc|Number=Sing	3	nmod	3:nmod	Entity=(CESSCASTP2002080117c21-person-1-CorefType:ident,gstype:spec)
# 7	en	en	ADP	sps00	_	9	case	9:case	_
# 8	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	9	det	9:det	Entity=(NOCOREF:Spec.other-other-2-gstype:spec
# 9	diario	diario	NOUN	ncms000	Gender=Masc|Number=Sing	3	nmod	3:nmod	_
# 10	Nueva	Nueva	PROPN	np00000	_	9	appos	9:appos	MWE=Nueva_Rioja|MWEPOS=PROPN|Entity=(NOCOREF:Spec.other-other-1-gstype:spec
# 11	Rioja	Rioja	PROPN	_	_	10	flat	10:flat	Entity=NOCOREF:Spec.other)NOCOREF:Spec.other)
# 12-13	del	_	_	_	_	_	_	_	_
# 12	de	de	ADP	spcms	_	14	case	14:case	_
# 13	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	14	det	14:det	_
# 14	9	9	NUM	_	NumForm=Digit|NumType=Card	3	nmod	3:nmod	MWE=9_de_marzo_de_1979|MWEPOS=NOUN|Entity=(NOCOREF:Spec.date-time-1-gstype:spec
# 15	de	de	ADP	_	_	16	case	16:case	_
# 16	marzo	marzo	NOUN	_	_	14	nmod	14:nmod	_
# 17	de	de	ADP	_	_	18	case	18:case	_
# 18	1979	1979	NUM	_	NumForm=Digit|NumType=Card	14	compound	14:compound	SpaceAfter=No|Entity=NOCOREF:Spec.date)CESSCASTP2002080117c22)
# 19	.	.	PUNCT	fp	PunctType=Peri	1	punct	1:punct	_
#
#
# # sent_id = CESS-CAST-P-20020801-17-s19
# # text = El artículo explicaba: "Vientos de revancha son los que parecen traer algunos de los ayuntamientos recientemente constituidos" .
# 1	El	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	2	det	2:det	Entity=(CESSCASTP2002080117c22--2-CorefType:ident,gstype:gen
# 2	artículo	artículo	NOUN	ncms000	Gender=Masc|Number=Sing	3	nsubj	3:nsubj	ArgTem=arg0:agt|Entity=CESSCASTP2002080117c22)
# 3	explicaba	explicar	VERB	vmii3s0	Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin	0	root	0:root	SpaceAfter=No
# 4	:	:	PUNCT	fd	PunctType=Colo	10	punct	10:punct	_
# 5	"	"	PUNCT	fe	PunctType=Quot	10	punct	10:punct	SpaceAfter=No
# 6	Vientos	viento	NOUN	ncmp000	Gender=Masc|Number=Plur	10	nsubj	10:nsubj	ArgTem=arg1:tem|Entity=(NOCOREF:Gen--1-gstype:gen
# 7	de	de	ADP	sps00	_	8	case	8:case	_
# 8	revancha	revancha	NOUN	ncfs000	Gender=Fem|Number=Sing	6	nmod	6:nmod	Entity=NOCOREF:Gen)
# 9	son	ser	AUX	vsip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	10	cop	10:cop	ArgTem=arg1:pat
# 10	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	3	ccomp	3:ccomp	_
# 11	que	que	PRON	pr0cn000	PronType=Rel	13	obj	13:obj	ArgTem=arg1:pat
# 12	parecen	parecer	VERB	vmip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	10	acl:relcl	10:acl:relcl	ArgTem=arg2:atr
# 13	traer	traer	VERB	vmn0000	VerbForm=Inf	12	xcomp	12:xcomp	ArgTem=arg2:atr
# 14	algunos	alguno	PRON	pi0mp000	Gender=Masc|Number=Plur|PronType=Ind	12	nsubj	12:nsubj	ArgTem=arg1:tem|Entity=(NOCOREF:Gen--1-gstype:gen
# 15	de	de	ADP	sps00	_	17	case	17:case	_
# 16	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	17	det	17:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 17	ayuntamientos	ayuntamiento	NOUN	ncmp000	Gender=Masc|Number=Plur	14	nmod	14:nmod	_
# 18	recientemente	recientemente	ADV	rg	_	19	advmod	19:advmod	ArgTem=argM:tmp
# 19	constituidos	constituido	ADJ	aq0mpp	Gender=Masc|Number=Plur|VerbForm=Part	17	amod	17:amod	SpaceAfter=No|Entity=NOCOREF:Gen)NOCOREF:Gen)
# 20	"	"	PUNCT	fe	PunctType=Quot	10	punct	10:punct	_
# 21	.	.	PUNCT	fp	PunctType=Peri	3	punct	3:punct	_
#
#
# # sent_id = CESS-CAST-P-20020801-17-s20
# # text = " El de Guernica aprueba por unanimidad retirar la medalla de la villa así como todos los honores concedidos al anterior jefe del Estado que, aunque moleste a muchos, gobernó 40 años y se llamaba Francisco Franco".
# 1	"	"	PUNCT	fe	PunctType=Quot	5	punct	5:punct	_
# 2	El	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	5	det	5:det	Entity=(NOCOREF:Gen--1-gstype:gen
# 3	de	de	ADP	sps00	_	2	case	2:case	_
# 4	Guernica	Guernica	PROPN	np00000	_	2	nsubj	2:nsubj	ArgTem=arg0:agt|Entity=(CESSCASTP2002080117c23-place-1-gstype:spec)NOCOREF:Gen)
# 5	aprueba	aprobar	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	0:root	_
# 6	por	por	ADP	sps00	_	7	case	7:case	_
# 7	unanimidad	unanimidad	NOUN	ncfs000	Gender=Fem|Number=Sing	5	obl	5:obl	ArgTem=argM:mnr
# 8	retirar	retirar	VERB	vmn0000	VerbForm=Inf	5	xcomp	5:xcomp	ArgTem=arg1:pat
# 9	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	10	det	10:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 10	medalla	medalla	NOUN	ncfs000	Gender=Fem|Number=Sing	8	obj	8:obj	ArgTem=arg1:pat
# 11	de	de	ADP	sps00	_	13	case	13:case	_
# 12	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	13	det	13:det	Entity=(CESSCASTP2002080117c23-place-2-CorefType:ident,gstype:spec
# 13	villa	villa	NOUN	ncfs000	Gender=Fem|Number=Sing	10	nmod	10:nmod	Entity=CESSCASTP2002080117c23)NOCOREF:Gen)
# 14	así	así	ADV	cc	_	18	cc	18:cc	MWE=así_como|MWEPOS=CCONJ
# 15	como	como	SCONJ	_	_	14	fixed	14:fixed	_
# 16	todos	todo	DET	di0mp0	Gender=Masc|Number=Plur|PronType=Tot	17	det	17:det	Entity=(NOCOREF:Gen--3-gstype:gen
# 17	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	18	det	18:det	_
# 18	honores	honor	NOUN	ncmp000	Gender=Masc|Number=Plur	10	conj	10:conj	_
# 19	concedidos	concedido	ADJ	aq0mpp	Gender=Masc|Number=Plur|VerbForm=Part	18	amod	18:amod	_
# 20-21	al	_	_	_	_	_	_	_	_
# 20	a	a	ADP	spcms	_	23	case	23:case	_
# 21	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	23	det	23:det	_
# 22	anterior	anterior	ADJ	aq0cs0	Number=Sing	23	amod	23:amod	Entity=(CESSCASTP2002080117c24-person-2-gstype:spec
# 23	jefe	jefe	NOUN	ncms000	Gender=Masc|Number=Sing	19	obl:arg	19:obl:arg	ArgTem=arg2:ben
# 24-25	del	_	_	_	_	_	_	_	_
# 24	de	de	ADP	spcms	_	26	case	26:case	_
# 25	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	26	det	26:det	_
# 26	Estado	Estado	PROPN	np00000	_	23	nmod	23:nmod	Entity=(NOCOREF:Spec.organization-organization-1-gstype:spec)
# 27	que	que	PRON	pr0cn000	PronType=Rel	34	nsubj	34:nsubj	SpaceAfter=No|ArgTem=arg0:agt|Entity=(CESSCASTP2002080117c24-person-1-CorefType:ident,gstype:spec)
# 28	,	,	PUNCT	fc	PunctType=Comm	30	punct	30:punct	_
# 29	aunque	aunque	SCONJ	cs	_	30	mark	30:mark	_
# 29.1	_	_	PRON	p	_	_	_	30:nsubj	ArgTem=arg0:cau|Entity=(CESSCASTP2002080117c24-person-1-CorefType:ident,gstype:spec)
# 30	moleste	molestar	VERB	vmsp3s0	Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	34	advcl	34:advcl	_
# 31	a	a	ADP	sps00	_	32	case	32:case	_
# 32	muchos	mucho	PRON	pi0mp000	Gender=Masc|Number=Plur|NumType=Card|PronType=Ind	30	obj	30:obj	SpaceAfter=No|ArgTem=arg1:tem|Entity=(NOCOREF:Gen--1-gstype:gen)
# 33	,	,	PUNCT	fc	PunctType=Comm	30	punct	30:punct	_
# 34	gobernó	gobernar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	23	acl	23:acl	_
# 35	40	40	NUM	_	NumForm=Digit|NumType=Card	36	nummod	36:nummod	Entity=(NOCOREF:Spec.number-number-2-gstype:spec
# 36	años	año	NOUN	ncmp000	Gender=Masc|Number=Plur	34	obl	34:obl	ArgTem=argM:tmp|Entity=NOCOREF:Spec.number)
# 37	y	y	CCONJ	cc	_	39	cc	39:cc	_
# 38	se	él	PRON	p0300000	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	39	expl:pv	39:expl:pv	_
# 39	llamaba	llamar	VERB	vmii3s0	Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin	34	conj	34:conj	_
# 40	Francisco	Francisco	PROPN	np00000	_	39	obj	39:obj	MWE=Francisco_Franco|MWEPOS=PROPN|ArgTem=arg2:atr|Entity=(NOCOREF:Spec.person-person-1-gstype:spec
# 41	Franco	Franco	PROPN	_	_	40	flat	40:flat	SpaceAfter=No|Entity=NOCOREF:Spec.person)CESSCASTP2002080117c24)NOCOREF:Gen)
# 42	"	"	PUNCT	fe	PunctType=Quot	5	punct	5:punct	SpaceAfter=No
# 43	.	.	PUNCT	fp	PunctType=Peri	5	punct	5:punct	_

# %%
#@title Estructura de los tokens etiquetados del corpus
tokenlist[1] #imprime el primer token de la lista (De la iteración que hicimos)
# Out:
# Token([('id', 2),
#        ('form', 'cierto'),
#        ('lemma', 'cierto'),
#        ('upos', 'ADJ'),
#        ('xpos', 'ADJ'),
#        ('feats', OrderedDict([('Gender', 'Masc'), ('Number', 'Sing')])),
#        ('head', 3),
#        ('deprel', 'nsubj'),
#        ('deps', None),
#        ('misc', None)])

# %%
tokenlist[1]['form']+'|'+tokenlist[1]['upos'] #Del token list dame el form junto a la categoria gramatical (igual que la formula de dado)
# Out:
# 'El|DET'

# %% [markdown]
# ## Entrenamiento del modelo - Calculo de conteos:
#
# * tags (tags) `tagCountDict`: $C(tag)$
# * emisiones (word|tag) `emissionProbDict`: $C(word|tag)$
# * transiciones (tag|prevtag) `transitionDict`: $C(tag|prevtag)$

# %%
tagCountDict = {} #Cuantas veces aparece esa etiqueta
emissionDict = {} #Cuantas veces dada una etiqueta corresponde cierta palabra
transitionDict = {} #Dada una etiqueta previa cual le corresponde una subsiguiente

tagtype = 'upos' #La convención de etiquetas universal upos
data_file = open("UD_Spanish-AnCora/es_ancora-ud-dev.conllu", "r", encoding="utf-8")

# Calculando conteos (pre-probabilidades)
for tokenlist in parse_incr(data_file): #Para recorrer ese corpus
  prevtag = None #Antes del primer token es nulo, no hay palabra anterior
  for token in tokenlist: #Leyendo token por token en la list

    # C(tag) cuantas veces aparece la etiqueta en el corpus
    tag = token[tagtype]
    if tag in tagCountDict.keys(): #A medida que se va iterando si el elemento ya esta en la lista
      tagCountDict[tag] += 1 #Se continua
    else:
      tagCountDict[tag] = 1 #En caso que no, se asigna que es la primera vez que aparece

    # C(word|tag) -> probabilidades emision
    wordtag = token['form'].lower()+'|'+token[tagtype] # (word|tag) la palabara en minuscula junto a la etiqueta gramatical
    if wordtag in emissionDict.keys(): #Se repite el proceso, si esta en la wortag continua sino asignala
      emissionDict[wordtag] = emissionDict[wordtag] + 1
    else:
      emissionDict[wordtag] = 1

    #  C(tag|tag_previo) -> probabilidades transición
    if prevtag is None: #Si el tag anterior es nulo, asignale el tag
      prevtag = tag
      continue #Salta la iteración
    transitiontags = tag+'|'+prevtag #La transición es el tag más el tag anterior
    if transitiontags in transitionDict.keys(): #Si la transición esta en la lista
      transitionDict[transitiontags] = transitionDict[transitiontags] + 1 #Se suma 1 a la transición
    else: #Si no esta en la lista
      transitionDict[transitiontags] = 1 #Se asigna 1 a la transición
    prevtag = tag #Se asigna el tag como el tag anterior

#transitionDict
#emissionDict
#tagCountDict

# %% [markdown]
# ## Entrenamiento del modelo - calculo de probabilidades
# * probabilidades de transición:
# $$P(tag|prevtag) = \frac{C(prevtag, tag)}{C(prevtag)}$$
#
# * probabilidades de emisión:
#  $$P(word|tag) = \frac{C(word|tag)}{C(tag)}$$

# %%
transitionProbDict = {} # matriz A
emissionProbDict = {} # matriz B

# transition Probabilities
for key in transitionDict.keys(): #Recorrer todas las llaves de transición
  tag, prevtag = key.split('|') #Los va a separar para obtener el tag y su tag anterior (split)
  if tagCountDict[prevtag]>0: #Para cada etiqueta anterior revise si dio mayor de cero (Si aparecio)
    transitionProbDict[key] = transitionDict[key]/(tagCountDict[prevtag]) #Calcular la probabilidad de transición
  else:
    print(key)

# emission Probabilities
for key in emissionDict.keys(): #Recorrer todas las llaves de transición
  word, tag = key.split('|') #Los va a separar para obtener la palabra y su tag
  if emissionDict[key]>0: #Para cada etiqueta anterior revise si dio mayor de cero (Si aparecio)
    emissionProbDict[key] = emissionDict[key]/tagCountDict[tag] #Calcular la probabilidad de transición
  else:
    print(key)

transitionProbDict['ADJ|ADJ']
#emissionProbDict
# Out:
# 0.030217452696978255

# %%
transitionProbDict
# Out:
# {'NOUN|DET': 0.7051234338171443,
#  'PUNCT|NOUN': 0.21745022412175544,
#  'ADP|PUNCT': 0.10090433127082342,
#  'ADJ|ADP': 0.012436935351402088,
#  'NOUN|ADJ': 0.21575826037842416,
#  'ADP|NOUN': 0.32356926925883456,
#  'SCONJ|ADP': 0.017834095975595446,
#  'VERB|SCONJ': 0.09595070422535211,
#  'VERB|VERB': 0.029147490685952224,
#  'NUM|VERB': 0.020600482138943676,
#  'NOUN|NUM': 0.5239130434782608,
#  '_|NOUN': 0.05962681121651204,
#  'ADP|_': 0.8613312202852615,
#  'DET|ADP': 0.5141382142438109,
#  'VERB|ADP': 0.057022175290390706,
#  '_|VERB': 0.03550295857988166,
#  'DET|NOUN': 0.014177004065464401,
#  'CCONJ|NOUN': 0.04951527155217346,
#  'ADJ|CCONJ': 0.08459422283356259,
#  'ADP|ADJ': 0.24936458627506355,
#  'NOUN|ADP': 0.19464977120732135,
#  'ADJ|NOUN': 0.17043677681642866,
#  'PUNCT|ADJ': 0.24795255577520475,
#  'VERB|PUNCT': 0.06964937331429479,
#  'ADP|VERB': 0.24479509094893712,
#  'PRON|DET': 0.01786378861183476,
#  'DET|PRON': 0.024761904761904763,
#  'PROPN|DET': 0.12095273539263118,
#  'PROPN|PROPN': 0.22665345553628932,
#  'ADP|PROPN': 0.12335892989843944,
#  'PROPN|ADP': 0.11310571395048692,
#  'PUNCT|PROPN': 0.36859053752786725,
#  'PROPN|PUNCT': 0.06203395208630811,
#  'ADV|VERB': 0.07911461757615604,
#  'DET|ADV': 0.08888888888888889,
#  'ADJ|PUNCT': 0.0318895763921942,
#  '_|ADP': 0.007743752199929602,
#  'VERB|_': 0.13708399366085577,
#  'PRON|VERB': 0.06618452772298926,
#  'NUM|DET': 0.03101352189554646,
#  'ADP|NUM': 0.1782608695652174,
#  'PRON|PROPN': 0.027743373792420114,
#  'VERB|PRON': 0.44634920634920633,
#  'ADJ|DET': 0.08733407765785883,
#  'NOUN|NOUN': 0.009173355571771083,
#  'ADV|DET': 0.006078650291527106,
#  'ADJ|ADV': 0.13216374269005848,
#  'PUNCT|ADP': 0.004810512730259299,
#  'DET|VERB': 0.26605303528380453,
#  'VERB|CCONJ': 0.05089408528198074,
#  'PUNCT|DET': 0.009304056568663937,
#  'NOUN|PUNCT': 0.0461684911946692,
#  'ADV|ADP': 0.012788924087762525,
#  'VERB|ADV': 0.156140350877193,
#  'AUX|PRON': 0.12698412698412698,
#  'DET|AUX': 0.12666666666666668,
#  'PRON|NOUN': 0.049411028875221516,
#  'CCONJ|PUNCT': 0.05140409328891004,
#  'SCONJ|CCONJ': 0.039889958734525444,
#  'PRON|SCONJ': 0.24911971830985916,
#  'ADJ|VERB': 0.024764409379793996,
#  'CCONJ|ADJ': 0.06693024569330698,
#  'ADV|CCONJ': 0.055020632737276476,
#  'VERB|NOUN': 0.035025539455853225,
#  'ADV|ADV': 0.056140350877192984,
#  '_|PUNCT': 0.011581786450896399,
#  'SCONJ|PUNCT': 0.03046168491194669,
#  'DET|SCONJ': 0.30633802816901406,
#  'PUNCT|PUNCT': 0.10471204188481675,
#  'PROPN|CCONJ': 0.10866574965612105,
#  'PRON|PUNCT': 0.08154846898302395,
#  'PRON|AUX': 0.014166666666666666,
#  'ADV|PRON': 0.06888888888888889,
#  'DET|DET': 0.012033246495472025,
#  'SCONJ|VERB': 0.07758053911900066,
#  'ADJ|ADJ': 0.030217452696978255,
#  'CCONJ|NUM': 0.02608695652173913,
#  'DET|CCONJ': 0.19807427785419532,
#  'NOUN|VERB': 0.053035283804514576,
#  'PROPN|NUM': 0.009782608695652175,
#  'NOUN|CCONJ': 0.11485557083906466,
#  'VERB|AUX': 0.4791666666666667,
#  'ADV|NOUN': 0.0212655060981966,
#  'ADP|ADV': 0.15789473684210525,
#  'PROPN|SCONJ': 0.05985915492957746,
#  'VERB|PROPN': 0.09041367351994055,
#  'ADV|PROPN': 0.014862521674510775,
#  'PRON|ADV': 0.09239766081871345,
#  'VERB|DET': 0.003597568539883389,
#  '_|PROPN': 0.019568986871439188,
#  'PUNCT|VERB': 0.06793776024545255,
#  'ADV|PUNCT': 0.038235760748849754,
#  'PUNCT|ADV': 0.10350877192982456,
#  'AUX|PROPN': 0.02402774337379242,
#  'AUX|ADP': 0.0046931831514724865,
#  'ADP|ADP': 0.0018772732605889944,
#  'PROPN|ADJ': 0.02795820389720418,
#  'ADV|ADJ': 0.01750917819824908,
#  'DET|ADJ': 0.014402711098559728,
#  'ADP|CCONJ': 0.08459422283356259,
#  'PRON|PRON': 0.14825396825396825,
#  'AUX|SCONJ': 0.03169014084507042,
#  'DET|PUNCT': 0.080755195938442,
#  '_|ADJ': 0.030782264896921773,
#  'PRON|ADP': 0.023231256599788808,
#  'AUX|CCONJ': 0.008253094910591471,
#  'AUX|AUX': 0.051666666666666666,
#  'NOUN|AUX': 0.03,
#  'PROPN|NOUN': 0.01615761492755134,
#  'SCONJ|ADV': 0.047953216374269005,
#  'ADP|AUX': 0.028333333333333332,
#  'AUX|NOUN': 0.018763681851349943,
#  'ADJ|AUX': 0.13,
#  'ADV|SCONJ': 0.05017605633802817,
#  'ADP|PRON': 0.06761904761904762,
#  'PRON|ADJ': 0.029652640497034737,
#  'PROPN|VERB': 0.019943019943019943,
#  'CCONJ|PROPN': 0.06044092147634382,
#  'NOUN|ADV': 0.02631578947368421,
#  'INTJ|PRON': 0.0009523809523809524,
#  'PRON|INTJ': 0.4,
#  '_|CCONJ': 0.024071526822558458,
#  'PRON|CCONJ': 0.17744154057771663,
#  'SCONJ|AUX': 0.020833333333333332,
#  'VERB|ADJ': 0.03247670149675233,
#  'PUNCT|SCONJ': 0.05721830985915493,
#  'SCONJ|DET': 0.0003721622627465575,
#  'AUX|ADJ': 0.014685117198531489,
#  'SCONJ|ADJ': 0.018073990398192602,
#  'AUX|ADV': 0.0824561403508772,
#  'SCONJ|SCONJ': 0.01584507042253521,
#  'AUX|PUNCT': 0.01776931619863557,
#  'ADJ|PROPN': 0.015357939063661135,
#  '_|DET': 0.002108919488897159,
#  'PUNCT|PRON': 0.06412698412698413,
#  'SCONJ|PRON': 0.004126984126984127,
#  'AUX|VERB': 0.005917159763313609,
#  '_|AUX': 0.03166666666666667,
#  'CCONJ|PRON': 0.006349206349206349,
#  'PUNCT|INTJ': 0.3,
#  'PUNCT|CCONJ': 0.02544704264099037,
#  '_|SCONJ': 0.007922535211267605,
#  'NOUN|SCONJ': 0.04929577464788732,
#  'ADP|SCONJ': 0.06602112676056338,
#  'PUNCT|AUX': 0.024166666666666666,
#  'AUX|_': 0.001584786053882726,
#  'PUNCT|NUM': 0.11739130434782609,
#  'ADJ|PRON': 0.015555555555555555,
#  'NUM|ADP': 0.03555086237240408,
#  'ADV|NUM': 0.005434782608695652,
#  'ADV|AUX': 0.056666666666666664,
#  'PROPN|ADV': 0.006432748538011696,
#  'PART|NOUN': 0.00010424267695194412,
#  'ADV|PART': 0.42857142857142855,
#  'NUM|PRON': 0.010793650793650795,
#  'CCONJ|ADV': 0.014619883040935672,
#  'SCONJ|NOUN': 0.0106327530490983,
#  'NUM|ADJ': 0.003388873199661113,
#  'NUM|NOUN': 0.004273949755029709,
#  'INTJ|CCONJ': 0.000687757909215956,
#  'SCONJ|INTJ': 0.1,
#  'PROPN|PRON': 0.002857142857142857,
#  'INTJ|PUNCT': 0.00047596382674916705,
#  'CCONJ|VERB': 0.009204470742932281,
#  'NOUN|PRON': 0.006349206349206349,
#  'ADP|DET': 0.0033494603647190174,
#  'CCONJ|AUX': 0.0016666666666666668,
#  'DET|PROPN': 0.01189001733960862,
#  '_|PRON': 0.005714285714285714,
#  'PART|PUNCT': 0.0009519276534983341,
#  '_|ADV': 0.02865497076023392,
#  'SCONJ|PROPN': 0.007678969531830567,
#  'DET|NUM': 0.006521739130434782,
#  'NUM|PUNCT': 0.011105822624147232,
#  'NUM|CCONJ': 0.027510316368638238,
#  'NUM|ADV': 0.006432748538011696,
#  'NUM|NUM': 0.009782608695652175,
#  'ADJ|NUM': 0.03260869565217391,
#  '_|NUM': 0.015217391304347827,
#  'PART|VERB': 0.00021915406530791147,
#  'NOUN|PART': 0.5,
#  'CCONJ|SCONJ': 0.0017605633802816902,
#  'PROPN|AUX': 0.004166666666666667,
#  'AUX|NUM': 0.009782608695652175,
#  'NUM|PROPN': 0.005449591280653951,
#  'VERB|NUM': 0.016304347826086956,
#  'SCONJ|NUM': 0.0010869565217391304,
#  'ADJ|SCONJ': 0.008802816901408451,
#  'NOUN|PROPN': 0.0014862521674510775,
#  'AUX|DET': 0.0003721622627465575,
#  'SYM|NOUN': 0.00010424267695194412,
#  'CCONJ|SYM': 0.0975609756097561,
#  'VERB|INTJ': 0.1,
#  'PRON|NUM': 0.007608695652173913,
#  'SYM|ADJ': 0.0002824060999717594,
#  'PROPN|SYM': 0.024390243902439025,
#  'SYM|DET': 0.0003721622627465575,
#  'PUNCT|SYM': 0.1951219512195122,
#  'SYM|NUM': 0.0391304347826087,
#  '_|SYM': 0.14634146341463414,
#  'PRON|SYM': 0.024390243902439025,
#  'ADP|SYM': 0.43902439024390244,
#  'NUM|AUX': 0.0008333333333333334,
#  'PART|ADP': 0.00011732957878681215,
#  'PRON|PART': 0.07142857142857142,
#  'PART|PRON': 0.00031746031746031746,
#  'CCONJ|DET': 0.00012405408758218582,
#  'NOUN|SYM': 0.024390243902439025,
#  'ADV|SYM': 0.024390243902439025,
#  'ADJ|SYM': 0.024390243902439025,
#  'PART|PROPN': 0.00024770869457517957,
#  'INTJ|PROPN': 0.00024770869457517957,
#  'INTJ|NOUN': 0.00010424267695194412,
#  'ADP|INTJ': 0.1}

# %% [markdown]
# ## Guardar parámetros del modelo

# %%
import numpy as np
np.save('transitionHMM.npy', transitionProbDict) #Grabar cada propiedad en un archivo
np.save('emissionHMM.npy', emissionProbDict) #Grabar las propiedades en el archivo
transitionProbdict = np.load('transitionHMM.npy', allow_pickle='TRUE').item()
transitionProbDict['ADJ|ADJ']
# Out:
# 0.030217452696978255
